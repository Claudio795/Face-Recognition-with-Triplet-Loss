# %% [markdown]
# # IA Project - Face Recognition with Dynamic Triplet Loss

# %% [markdown]
# References: https://openaccess.thecvf.com/content_ICCV_2019/papers/Zhang_Learning_Local_Descriptors_With_a_CDF-Based_Dynamic_Soft_Margin_ICCV_2019_paper.pdf
#
# Dataset: http://vis-www.cs.umass.edu/lfw/#download

# %%
import torch
from matplotlib import pyplot as plt
from torchvision import datasets
import torchvision.transforms.functional as TF
import torchvision.transforms as T
import numpy as np
import os

# %%
dev = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(dev)
# Out:
# cpu

# %% [markdown]
# ### Pre-precessing data

# %%
#path
data_path = "./LFW_DIR"
train_path = "./data/train_pairs.txt"
test_path = "./data/test_pairs.txt"
people_path = "./data/people.txt"

# %%
# loading dataset
# dataset = datasets.ImageFolder(data_path, transform = transform)
dataset = datasets.ImageFolder(data_path)
print(f"num samples: {len(dataset)}")
# Out:
# num samples: 13233

# %%
dataset[8][0]

# %%
norm_mean = (0.485, 0.456, 0.406)
norm_std = (0.229, 0.224, 0.225)

transform = T.Compose([
    T.Scale((250, 250)),  # make 250x250
    T.CenterCrop(150),   # then take 150x150 center crop
    T.ToTensor(),
    T.Normalize(norm_mean, norm_std),
])

# %%
def read_pairsLFW(pairs_path):
    pairs = []
    with open(pairs_path, 'r') as file:
        for line in file.readlines()[1:]:
            pair = line.strip().split()
            pairs.append(pair)
    return pairs

# %%
pairs = read_pairsLFW(train_path)
pairs
# Out:
# [['Aaron_Peirsol', '1', '2'],
#  ['Aaron_Peirsol', '3', '4'],
#  ['Aaron_Sorkin', '1', '2'],
#  ['Abdel_Nasser_Assidi', '1', '2'],
#  ['Abdullah', '1', '3'],
#  ['Abdullah', '2', '4'],
#  ['Abdullah_al-Attiyah', '1', '3'],
#  ['Abdullah_al-Attiyah', '2', '3'],
#  ['Abel_Pacheco', '1', '4'],
#  ['Abel_Pacheco', '3', '4'],
#  ['Adam_Sandler', '1', '3'],
#  ['Adam_Sandler', '1', '4'],
#  ['Adam_Sandler', '2', '4'],
#  ['Adam_Scott', '1', '2'],
#  ['Adolfo_Aguilar_Zinser', '1', '3'],
#  ['Ahmed_Chalabi', '2', '4'],
#  ['Ai_Sugiyama', '2', '4'],
#  ['Aicha_El_Ouafi', '1', '3'],
#  ['Aicha_El_Ouafi', '2', '3'],
#  ['Akbar_Hashemi_Rafsanjani', '1', '3'],
#  ['Akhmed_Zakayev', '1', '3'],
#  ['Akhmed_Zakayev', '2', '3'],
#  ['Al_Gore', '1', '3'],
#  ['Alan_Ball', '1', '2'],
#  ['Alberto_Fujimori', '1', '2'],
#  ['Alberto_Ruiz_Gallardon', '1', '2'],
#  ['Albrecht_Mentz', '1', '2'],
#  ['Alec_Baldwin', '1', '2'],
#  ['Alec_Baldwin', '1', '4'],
#  ['Alec_Baldwin', '2', '3'],
#  ['Alec_Baldwin', '3', '4'],
#  ['Alejandro_Toledo', '20', '38'],
#  ['Alex_Barros', '1', '2'],
#  ['Alex_Sink', '2', '3'],
#  ['Alexandra_Stevenson', '1', '2'],
#  ['Alexandra_Stevenson', '1', '3'],
#  ['Alexandra_Vodjanikova', '1', '2'],
#  ['Ali_Abbas', '1', '2'],
#  ['Ali_Khamenei', '1', '2'],
#  ['Alice_Fisher', '1', '2'],
#  ['Alicia_Silverstone', '1', '2'],
#  ['Alimzhan_Tokhtakhounov', '1', '2'],
#  ['Alison_Lohman', '1', '2'],
#  ['Alvaro_Noboa', '1', '2'],
#  ['Alvaro_Noboa', '2', '3'],
#  ['Alvaro_Silva_Calderon', '3', '4'],
#  ['Amanda_Beard', '1', '2'],
#  ['Amber_Tamblyn', '1', '2'],
#  ['Amelia_Vega', '2', '4'],
#  ['Amelia_Vega', '5', '7'],
#  ['Amelia_Vega', '6', '7'],
#  ['Amer_al-Saadi', '1', '2'],
#  ['Ana_Guevara', '1', '5'],
#  ['Ana_Guevara', '1', '6'],
#  ['Ana_Guevara', '2', '6'],
#  ['Ana_Guevara', '3', '6'],
#  ['Anastasia_Myskina', '1', '2'],
#  ['Anastasia_Myskina', '2', '3'],
#  ['Anders_Fogh_Rasmussen', '1', '2'],
#  ['Anders_Fogh_Rasmussen', '3', '4'],
#  ['Andre_Agassi', '9', '18'],
#  ['Andrew_Weissmann', '1', '3'],
#  ['Andy_Roddick', '3', '15'],
#  ['Andy_Roddick', '9', '14'],
#  ['Andy_Roddick', '12', '15'],
#  ['Angela_Bassett', '2', '6'],
#  ['Angelina_Jolie', '3', '15'],
#  ['Angelina_Jolie', '4', '16'],
#  ['Angelina_Jolie', '8', '15'],
#  ['Angelina_Jolie', '9', '17'],
#  ['Angelina_Jolie', '16', '17'],
#  ['Anibal_Ibarra', '2', '3'],
#  ['Anna_Kournikova', '5', '9'],
#  ['Annette_Bening', '1', '2'],
#  ['Anthony_Hopkins', '1', '2'],
#  ['Antonio_Banderas', '2', '3'],
#  ['Antonio_Banderas', '2', '4'],
#  ['Antony_Leung', '2', '3'],
#  ['Anwar_Ibrahim', '1', '2'],
#  ['Arantxa_Sanchez-Vicario', '1', '2'],
#  ['Ari_Fleischer', '1', '13'],
#  ['Ari_Fleischer', '2', '4'],
#  ['Ari_Fleischer', '4', '6'],
#  ['Ari_Fleischer', '8', '13'],
#  ['Arianna_Huffington', '1', '2'],
#  ['Arianna_Huffington', '2', '3'],
#  ['Arminio_Fraga', '2', '6'],
#  ['Arnold_Palmer', '1', '2'],
#  ['Arnold_Palmer', '1', '3'],
#  ['Arnoldo_Aleman', '1', '3'],
#  ['Arnoldo_Aleman', '2', '4'],
#  ['Aron_Ralston', '1', '2'],
#  ['Art_Hoffmann', '1', '2'],
#  ['Arturo_Gatti', '1', '2'],
#  ['Arturo_Gatti', '2', '3'],
#  ['Arye_Mekel', '1', '2'],
#  ['Asa_Hutchinson', '1', '2'],
#  ['Atal_Bihari_Vajpayee', '10', '20'],
#  ['Atal_Bihari_Vajpayee', '17', '24'],
#  ['Augusto_Roa_Bastos', '1', '2'],
#  ['Azra_Akin', '1', '4'],
#  ['Barbara_Walters', '1', '3'],
#  ['Barbara_Walters', '1', '4'],
#  ['Barbara_Walters', '3', '4'],
#  ['Barbra_Streisand', '1', '2'],
#  ['Barbra_Streisand', '2', '3'],
#  ['Barrett_Jackman', '1', '2'],
#  ['Barry_Zito', '1', '2'],
#  ['Bashar_Assad', '1', '3'],
#  ['Bashar_Assad', '3', '4'],
#  ['Ben_Glisan', '1', '2'],
#  ['Ben_Howland', '1', '2'],
#  ['Benazir_Bhutto', '1', '2'],
#  ['Benazir_Bhutto', '2', '5'],
#  ['Bernard_Landry', '1', '2'],
#  ['Bernard_Landry', '1', '4'],
#  ['Bernard_Law', '1', '2'],
#  ['Bernard_Law', '2', '5'],
#  ['Bernardo_Segura', '1', '2'],
#  ['Beth_Jones', '1', '2'],
#  ['Bijan_Darvish', '1', '3'],
#  ['Bijan_Namdar_Zangeneh', '1', '2'],
#  ['Bill_Belichick', '1', '2'],
#  ['Bill_Callahan', '1', '2'],
#  ['Bill_Callahan', '1', '3'],
#  ['Bill_Clinton', '4', '20'],
#  ['Bill_Gates', '3', '11'],
#  ['Bill_Gates', '4', '15'],
#  ['Bill_Graham', '1', '7'],
#  ['Bill_Graham', '8', '9'],
#  ['Bill_Nelson', '1', '2'],
#  ['Bill_Simon', '4', '15'],
#  ['Bill_Simon', '5', '13'],
#  ['Billy_Crystal', '3', '5'],
#  ['Billy_Crystal', '3', '6'],
#  ['Billy_Crystal', '5', '6'],
#  ['Billy_Graham', '1', '2'],
#  ['Binyamin_Ben-Eliezer', '2', '5'],
#  ['Binyamin_Ben-Eliezer', '3', '7'],
#  ['Bo_Ryan', '1', '2'],
#  ['Bob_Beauprez', '1', '2'],
#  ['Bob_Geldof', '1', '2'],
#  ['Bob_Graham', '1', '5'],
#  ['Bob_Graham', '1', '6'],
#  ['Bob_Graham', '2', '4'],
#  ['Bob_Graham', '3', '5'],
#  ['Bob_Huggins', '1', '2'],
#  ['Bob_Stoops', '5', '7'],
#  ['Bobby_Robson', '1', '2'],
#  ['Boris_Berezovsky', '1', '2'],
#  ['Branko_Crvenkovski', '1', '3'],
#  ['Brendan_Hansen', '1', '2'],
#  ['Brooke_Shields', '1', '2'],
#  ['Bruce_Van_De_Velde', '1', '2'],
#  ['Bruce_Weber', '1', '2'],
#  ['Bud_Selig', '1', '2'],
#  ['Bud_Selig', '1', '4'],
#  ['Bulent_Ecevit', '2', '4'],
#  ['Bulent_Ecevit', '2', '5'],
#  ['Bulent_Ecevit', '3', '6'],
#  ['Cameron_Diaz', '3', '4'],
#  ['Candie_Kung', '1', '2'],
#  ['Candie_Kung', '2', '3'],
#  ['Carla_Myers', '1', '2'],
#  ['Carlos_Menem', '1', '3'],
#  ['Carlos_Menem', '6', '12'],
#  ['Carlos_Ruiz', '2', '3'],
#  ['Carlos_Vives', '1', '2'],
#  ['Carlos_Vives', '2', '3'],
#  ['Carly_Fiorina', '1', '2'],
#  ['Carly_Fiorina', '1', '3'],
#  ['Carmen_Electra', '1', '6'],
#  ['Carol_Moseley_Braun', '1', '2'],
#  ['Carolina_Kluft', '1', '3'],
#  ['Caroline_Kennedy', '1', '3'],
#  ['Carson_Palmer', '2', '4'],
#  ['Cate_Blanchett', '2', '3'],
#  ['Cate_Blanchett', '2', '4'],
#  ['Catherine_Deneuve', '2', '5'],
#  ['Catherine_Zeta-Jones', '1', '4'],
#  ['Catherine_Zeta-Jones', '1', '8'],
#  ['Catherine_Zeta-Jones', '4', '9'],
#  ['Catherine_Zeta-Jones', '6', '9'],
#  ['Catherine_Zeta-Jones', '8', '10'],
#  ['Cecilia_Bolocco', '1', '3'],
#  ['Cesar_Gaviria', '2', '5'],
#  ['Cesar_Gaviria', '4', '8'],
#  ['Cesar_Gaviria', '6', '7'],
#  ['Charles_Grassley', '1', '2'],
#  ['Charles_Moose', '1', '3'],
#  ['Charles_Moose', '4', '10'],
#  ['Charles_Moose', '4', '11'],
#  ['Charles_Schumer', '1', '2'],
#  ['Charlotte_Rampling', '1', '2'],
#  ['Chen_Liang_Yu', '1', '2'],
#  ['Cherie_Blair', '1', '2'],
#  ['Cherie_Blair', '1', '3'],
#  ['Cherie_Blair', '2', '4'],
#  ['Cherie_Blair', '3', '4'],
#  ['Choi_Sung-hong', '1', '4'],
#  ['Choi_Sung-hong', '3', '4'],
#  ['Chris_Cooper', '1', '2'],
#  ['Chris_Rock', '1', '2'],
#  ['Chris_Tucker', '1', '2'],
#  ['Christian_Fittipaldi', '1', '2'],
#  ['Christine_Gregoire', '2', '3'],
#  ['Christopher_Patten', '1', '2'],
#  ['Christopher_Walken', '1', '4'],
#  ['Christopher_Walken', '2', '4'],
#  ['Chuck_Amato', '1', '2'],
#  ['Chuck_Yeager', '1', '2'],
#  ['Chung_Mong-hun', '1', '2'],
#  ['Cindy_Margolis', '1', '2'],
#  ['Ciro_Gomes', '2', '3'],
#  ['Ciro_Gomes', '2', '4'],
#  ['Ciro_Gomes', '3', '4'],
#  ['Claire_Hentzen', '1', '2'],
#  ['Clara_Harris', '1', '4'],
#  ['Clara_Harris', '2', '4'],
#  ['Claudia_Pechstein', '1', '2'],
#  ['Claudia_Schiffer', '1', '3'],
#  ['Clint_Eastwood', '1', '5'],
#  ['Clint_Eastwood', '1', '6'],
#  ['Clint_Eastwood', '3', '6'],
#  ['Colin_Farrell', '1', '7'],
#  ['Colin_Farrell', '3', '7'],
#  ['Colin_Jackson', '1', '2'],
#  ['Colin_Montgomerie', '2', '4'],
#  ['Colin_Montgomerie', '2', '5'],
#  ['Colin_Powell', '38', '212'],
#  ['Colin_Powell', '74', '205'],
#  ['Colin_Powell', '120', '166'],
#  ['Conan_OBrien', '1', '2'],
#  ['Constance_Marie', '2', '3'],
#  ['Coretta_Scott_King', '2', '3'],
#  ['Corinne_Coman', '1', '2'],
#  ['Costas_Simitis', '1', '3'],
#  ['Costas_Simitis', '2', '4'],
#  ['Cristina_Saralegui', '1', '2'],
#  ['Cruz_Bustamante', '1', '4'],
#  ['Dalai_Lama', '1', '2'],
#  ['Dale_Earnhardt_Jr', '1', '2'],
#  ['Dale_Earnhardt_Jr', '1', '3'],
#  ['Damon_van_Dam', '1', '2'],
#  ['Dan_Morales', '1', '2'],
#  ['Dan_Morales', '1', '3'],
#  ['Daniel_Day-Lewis', '1', '2'],
#  ['Daniel_Day-Lewis', '1', '3'],
#  ['Darrell_Issa', '1', '2'],
#  ['Darrell_Porter', '1', '2'],
#  ['Darren_Clarke', '1', '2'],
#  ['Daryl_Hannah', '1', '2'],
#  ['David_Anderson', '1', '2'],
#  ['David_Anderson', '2', '4'],
#  ['David_Beckham', '4', '17'],
#  ['David_Beckham', '4', '24'],
#  ['David_Beckham', '5', '10'],
#  ['David_Caruso', '1', '2'],
#  ['David_Coulthard', '1', '2'],
#  ['David_Dodge', '1', '2'],
#  ['David_Heymann', '1', '2'],
#  ['David_Hyde_Pierce', '3', '4'],
#  ['David_Myers', '1', '2'],
#  ['David_Nalbandian', '4', '9'],
#  ['David_Spade', '1', '2'],
#  ['David_Wells', '1', '2'],
#  ['David_Wells', '2', '5'],
#  ['Dean_Barkley', '1', '4'],
#  ['Dean_Barkley', '2', '3'],
#  ['Debbie_Reynolds', '1', '3'],
#  ['Debra_Brown', '1', '2'],
#  ['Demi_Moore', '1', '2'],
#  ['Demi_Moore', '2', '3'],
#  ['Demi_Moore', '2', '4'],
#  ['Dennis_Erickson', '1', '2'],
#  ['Dennis_Kucinich', '2', '5'],
#  ['Dennis_Kucinich', '6', '7'],
#  ['Derek_Lowe', '1', '2'],
#  ['Desiree_Lemosi', '1', '2'],
#  ['Dexter_Jackson', '1', '2'],
#  ['Diana_Krall', '1', '3'],
#  ['Diana_Krall', '1', '6'],
#  ['Diana_Krall', '2', '4'],
#  ['Diana_Munz', '2', '3'],
#  ['Dianne_Feinstein', '2', '3'],
#  ['Dick_Cheney', '1', '11'],
#  ['Dick_Cheney', '1', '14'],
#  ['Dolly_Parton', '1', '2'],
#  ['Dolma_Tsering', '1', '2'],
#  ['Don_Nickles', '1', '2'],
#  ['Don_Siegelman', '2', '3'],
#  ['Donald_Evans', '1', '2'],
#  ['Donald_Fehr', '3', '4'],
#  ['Doris_Roberts', '1', '2'],
#  ['Doug_Duncan', '1', '2'],
#  ['Drew_Barrymore', '1', '2'],
#  ['Duane_Lee_Chapman', '1', '2'],
#  ['Dwayne_Johnson', '1', '2'],
#  ['Eddy_Merckx', '1', '2'],
#  ['Edie_Falco', '1', '2'],
#  ['Edmund_Hillary', '2', '3'],
#  ['Edmund_Stoiber', '2', '3'],
#  ['Eduard_Shevardnadze', '1', '3'],
#  ['Eduard_Shevardnadze', '3', '4'],
#  ['Eduardo_Duhalde', '5', '11'],
#  ['Edward_Kennedy', '1', '2'],
#  ['Edward_Said', '1', '2'],
#  ['Edwina_Currie', '2', '3'],
#  ['Eileen_Coparropa', '2', '3'],
#  ['Elena_Bovina', '1', '2'],
#  ['Elijah_Wood', '2', '3'],
#  ['Elizabeth_Dole', '1', '3'],
#  ['Elizabeth_Hurley', '1', '2'],
#  ['Elizabeth_Hurley', '2', '3'],
#  ['Elizabeth_Hurley', '4', '5'],
#  ['Elizabeth_Shue', '1', '2'],
#  ['Ellen_DeGeneres', '1', '2'],
#  ['Elton_John', '1', '7'],
#  ['Elton_John', '3', '5'],
#  ['Elvis_Presley', '1', '2'],
#  ['Emanuel_Ginobili', '2', '4'],
#  ['Emile_Lahoud', '1', '2'],
#  ['Emily_Robison', '1', '2'],
#  ['Emma_Thompson', '1', '2'],
#  ['Emma_Thompson', '1', '3'],
#  ['Emmanuelle_Beart', '1', '2'],
#  ['Emmanuelle_Beart', '2', '3'],
#  ['Emmit_Smith', '1', '2'],
#  ['Enrique_Bolanos', '1', '2'],
#  ['Enrique_Bolanos', '2', '5'],
#  ['Enrique_Bolanos', '4', '5'],
#  ['Eric_Clapton', '1', '2'],
#  ['Eric_Rosser', '1', '2'],
#  ['Erika_Harold', '2', '5'],
#  ['Ernesto_Zedillo', '1', '2'],
#  ['Ernie_Els', '1', '3'],
#  ['Ethan_Hawke', '1', '4'],
#  ['Ethan_Hawke', '2', '4'],
#  ['Ethan_Hawke', '3', '4'],
#  ['Eunice_Barber', '1', '2'],
#  ['Eva_Dimas', '1', '2'],
#  ['Evander_Holyfield', '1', '2'],
#  ['Eve_Pelletier', '1', '2'],
#  ['Farouk_al-Sharaa', '1', '3'],
#  ['Farouk_al-Sharaa', '2', '3'],
#  ['Federico_Trillo', '1', '3'],
#  ['Felix_Mantilla', '1', '2'],
#  ['Fernando_Gonzalez', '2', '6'],
#  ['Fernando_Gonzalez', '4', '7'],
#  ['Fernando_Henrique_Cardoso', '1', '3'],
#  ['Fidel_Castro', '4', '14'],
#  ['Flavia_Delaroli', '1', '2'],
#  ['Frances_Fisher', '1', '2'],
#  ['Francis_Ford_Coppola', '1', '2'],
#  ['Francisco_Flores', '3', '4'],
#  ['Frank_Griswold', '1', '2'],
#  ['Frank_Solich', '1', '2'],
#  ['Frank_Solich', '3', '4'],
#  ['Franz_Muentefering', '1', '3'],
#  ['Franz_Muentefering', '1', '4'],
#  ['Franz_Muentefering', '2', '3'],
#  ['Fred_Thompson', '2', '3'],
#  ['Fujio_Cho', '1', '5'],
#  ['Gabriel_Valdes', '1', '2'],
#  ['Garry_Kasparov', '1', '2'],
#  ['Gary_Carter', '1', '2'],
#  ['Gary_Carter', '1', '3'],
#  ['Gary_Forsee', '1', '2'],
#  ['Gary_Locke', '1', '2'],
#  ['George_Clooney', '2', '8'],
#  ['George_Clooney', '3', '9'],
#  ['George_Clooney', '5', '7'],
#  ['George_Galloway', '1', '4'],
#  ['George_HW_Bush', '1', '10'],
#  ['George_HW_Bush', '5', '13'],
#  ['George_HW_Bush', '10', '13'],
#  ['George_Lopez', '1', '4'],
#  ['George_P_Bush', '1', '2'],
#  ['George_Pataki', '1', '5'],
#  ['George_Roy_Hill', '1', '2'],
#  ['George_Voinovich', '1', '2'],
#  ['George_Voinovich', '1', '3'],
#  ['Gerardo_Gambala', '1', '2'],
#  ['Gerry_Parsky', '1', '2'],
#  ['Gian_Marco', '2', '3'],
#  ['Gil_de_Ferran', '2', '3'],
#  ['Gisele_Bundchen', '1', '2'],
#  ['Gloria_Allred', '1', '2'],
#  ['Gloria_Macapagal_Arroyo', '29', '40'],
#  ['Gloria_Trevi', '1', '3'],
#  ['Gloria_Trevi', '2', '4'],
#  ['Gloria_Trevi', '3', '4'],
#  ['Goldie_Hawn', '2', '6'],
#  ['Gonzalo_Sanchez_de_Lozada', '3', '10'],
#  ['Gonzalo_Sanchez_de_Lozada', '4', '8'],
#  ['Gonzalo_Sanchez_de_Lozada', '7', '8'],
#  ['Goran_Persson', '1', '2'],
#  ['Grady_Irvin_Jr', '1', '2'],
#  ['Grant_Hackett', '2', '3'],
#  ['Greg_Rusedski', '1', '4'],
#  ['Greg_Rusedski', '2', '4'],
#  ['Greg_Rusedski', '3', '4'],
#  ['Gregg_Popovich', '3', '4'],
#  ['Guillaume_Soro', '1', '2'],
#  ['Guillermo_Canas', '1', '2'],
#  ['Guillermo_Canas', '1', '4'],
#  ['Guillermo_Canas', '2', '4'],
#  ['Guillermo_Coria', '19', '29'],
#  ['Guillermo_Coria', '21', '27'],
#  ['Guillermo_Ortiz', '1', '2'],
#  ['Gunter_Pleuger', '2', '5'],
#  ['Gustavo_Kuerten', '1', '2'],
#  ['Gustavo_Kuerten', '2', '3'],
#  ['Habib_Rizieq', '4', '5'],
#  ['Hal_Gehman', '1', '3'],
#  ['Hal_Sutton', '1', '2'],
#  ['Halle_Berry', '1', '10'],
#  ['Halle_Berry', '7', '15'],
#  ['Halle_Berry', '10', '16'],
#  ['Hamid_Karzai', '1', '2'],
#  ['Hamzah_Haz', '1', '2'],
#  ['Hanan_Ashrawi', '1', '2'],
#  ['Hans_Blix', '2', '3'],
#  ['Hans_Blix', '6', '36'],
#  ['Hans_Blix', '14', '36'],
#  ['Harbhajan_Singh', '1', '2'],
#  ['Hashim_Thaci', '1', '2'],
#  ['Hassan_Nasrallah', '1', '2'],
#  ['Heath_Ledger', '1', '2'],
#  ['Hector_Babenco', '1', '2'],
#  ['Hee-Won_Han', '1', '3'],
#  ['Heidi_Klum', '1', '3'],
#  ['Helen_Clark', '3', '4'],
#  ['Henrique_Meirelles', '1', '2'],
#  ['Herta_Daeubler-Gmelin', '1', '2'],
#  ['Hideki_Matsui', '1', '2'],
#  ['Hilary_Duff', '1', '3'],
#  ['Hilary_Duff', '2', '3'],
#  ['Hillary_Clinton', '1', '14'],
#  ['Hillary_Clinton', '8', '14'],
#  ['Hilmi_Ozkok', '1', '2'],
#  ['Hipolito_Mejia', '1', '3'],
#  ['Hisao_Oguchi', '1', '2'],
#  ['Holly_Hunter', '2', '3'],
#  ['Holly_Hunter', '2', '5'],
#  ['Holly_Hunter', '4', '7'],
#  ['Hootie_Johnson', '1', '2'],
#  ['Hosni_Mubarak', '8', '9'],
#  ['Hu_Jintao', '1', '2'],
#  ['Hu_Jintao', '1', '12'],
#  ['Hu_Jintao', '2', '3'],
#  ['Hugh_Grant', '1', '7'],
#  ['Hugh_Grant', '1', '9'],
#  ['Hun_Sen', '1', '2'],
#  ['Hun_Sen', '1', '4'],
#  ['Ian_McKellen', '1', '2'],
#  ['Ian_McKellen', '1', '3'],
#  ['Ian_McKellen', '2', '3'],
#  ['Ibrahim_Jaafari', '1', '2'],
#  ['Igor_Ivanov', '5', '16'],
#  ['Ilan_Ramon', '1', '3'],
#  ['Inam-ul-Haq', '1', '2'],
#  ['Inocencio_Arias', '1', '2'],
#  ['Intisar_Ajouri', '2', '3'],
#  ['Jack_Straw', '4', '22'],
#  ['Jackie_Chan', '1', '10'],
#  ['Jackie_Chan', '7', '12'],
#  ['Jacqueline_Obradors', '1', '2'],
#  ['Jada_Pinkett_Smith', '1', '2'],
#  ['James_Caan', '1', '2'],
#  ['James_Cunningham', '1', '2'],
#  ['James_Cunningham', '2', '3'],
#  ['James_Gandolfini', '1', '3'],
#  ['James_Jones', '1', '2'],
#  ['James_Parker', '1', '2'],
#  ['James_Schultz', '1', '2'],
#  ['James_Traficant', '1', '2'],
#  ['James_Traficant', '1', '3'],
#  ['James_Wolfensohn', '1', '3'],
#  ['Jan-Michael_Gambill', '1', '3'],
#  ['Jane_Fonda', '1', '2'],
#  ['Jane_Pauley', '1', '2'],
#  ['Janet_Napolitano', '1', '4'],
#  ['Janet_Napolitano', '2', '3'],
#  ['Jason_Jennings', '1', '2'],
#  ['Jason_Kidd', '1', '4'],
#  ['Jason_Kidd', '1', '10'],
#  ['Jason_Kidd', '5', '6'],
#  ['Jason_Kidd', '6', '9'],
#  ['Jason_Kidd', '6', '10'],
#  ['Javier_Solana', '2', '6'],
#  ['Javier_Solana', '6', '7'],
#  ['Jay_Leno', '2', '3'],
#  ['Jayson_Williams', '1', '2'],
#  ['Jean-Claude_Braquet', '1', '2'],
#  ['Jean-David_Levitte', '3', '4'],
#  ['Jean-David_Levitte', '6', '7'],
#  ['Jean-David_Levitte', '8', '10'],
#  ['Jean-Francois_Pontal', '1', '3'],
#  ['Jean-Sebastien_Giguere', '1', '2'],
#  ['Jean_Brumley', '1', '2'],
#  ['Jean_Chretien', '3', '8'],
#  ['Jean_Chretien', '22', '30'],
#  ['Jean_Chretien', '31', '50'],
#  ['Jeanne_Moreau', '1', '2'],
#  ['Jeb_Bush', '4', '12'],
#  ['Jeff_Van_Gundy', '1', '3'],
#  ['Jeffrey_Archer', '1', '2'],
#  ['Jeffrey_Immelt', '1', '2'],
#  ['Jeffrey_Jones', '1', '2'],
#  ['Jennifer_Aniston', '5', '13'],
#  ['Jennifer_Garner', '1', '6'],
#  ['Jennifer_Garner', '1', '10'],
#  ['Jennifer_Garner', '4', '5'],
#  ['Jennifer_Garner', '5', '11'],
#  ['Jennifer_Lopez', '4', '7'],
#  ['Jennifer_Lopez', '5', '15'],
#  ['Jennifer_Lopez', '10', '21'],
#  ['Jerry_Regier', '2', '3'],
#  ['Jessica_Lynch', '1', '2'],
#  ['Jia_Qinglin', '1', '2'],
#  ['Jim_Carrey', '2', '3'],
#  ['Jim_Edmonds', '1', '2'],
#  ['Jim_Furyk', '1', '6'],
#  ['Jim_OBrien', '1', '3'],
#  ['Jim_OBrien', '2', '3'],
#  ['Jim_Tressel', '1', '2'],
#  ['Jim_Tressel', '2', '3'],
#  ['Jiri_Novak', '1', '10'],
#  ['Jiri_Novak', '4', '7'],
#  ['Jiri_Novak', '9', '11'],
#  ['Jo_Dee_Messina', '1', '2'],
#  ['Joan_Claybrook', '1', '2'],
#  ['Joan_Laporta', '2', '7'],
#  ['Job_Cohen', '1', '2'],
#  ['Joe_Calzaghe', '1', '2'],
#  ['Joe_Dumars', '1', '2'],
#  ['Joe_Gatti', '1', '2'],
#  ['Joe_Torre', '2', '3'],
#  ['Joe_Torre', '2', '4'],
#  ['Joerg_Haider', '1', '2'],
#  ['John_Abizaid', '3', '9'],
#  ['John_Ashcroft', '18', '21'],
#  ['John_Ashcroft', '25', '27'],
#  ['John_Ashcroft', '35', '53'],
#  ['John_Cusack', '1', '2'],
#  ['John_F_Kennedy_Jr', '1', '2'],
#  ['John_Kerry', '1', '2'],
#  ['John_Kerry', '5', '14'],
#  ['John_Manley', '2', '7'],
#  ['John_Manley', '3', '4'],
#  ['John_Manley', '4', '5'],
#  ['John_McCain', '3', '4'],
#  ['John_McCain', '5', '6'],
#  ['John_McCormack', '1', '2'],
#  ['John_Paul_II', '3', '11'],
#  ['John_Reid', '1', '2'],
#  ['John_Rigas', '1', '2'],
#  ['John_Rosa', '2', '3'],
#  ['John_Ruiz', '1', '2'],
#  ['John_Snow', '2', '4'],
#  ['John_Snow', '4', '7'],
#  ['John_Snow', '8', '16'],
#  ['John_Snow', '14', '17'],
#  ['John_Swofford', '1', '3'],
#  ['John_Taylor', '1', '2'],
#  ['John_Warner', '1', '2'],
#  ['John_Warner', '1', '4'],
#  ['John_Warner', '2', '3'],
#  ['Johnny_Tapia', '1', '3'],
#  ['Johnny_Tapia', '2', '3'],
#  ['Jon_Gruden', '2', '7'],
#  ['Jonathan_Edwards', '2', '4'],
#  ['Jonathan_Mostow', '1', '2'],
#  ['Jong_Wook_Lee', '1', '3'],
#  ['Jorge_Batlle', '1', '3'],
#  ['Jorge_Batlle', '2', '3'],
#  ['Joschka_Fischer', '14', '15'],
#  ['Jose_Canseco', '1', '2'],
#  ['Jose_Manuel_Durao_Barroso', '1', '6'],
#  ['Jose_Manuel_Durao_Barroso', '2', '5'],
#  ['Jose_Manuel_Durao_Barroso', '3', '5'],
#  ['Jose_Maria_Aznar', '4', '22'],
#  ['Jose_Maria_Aznar', '14', '20'],
#  ['Jose_Mourinho', '1', '2'],
#  ['Jose_Sarney', '1', '2'],
#  ['Jose_Serra', '1', '9'],
#  ['Jose_Viegas_Filho', '1', '2'],
#  ['Joseph_Biden', '1', '3'],
#  ['Joseph_Biden', '2', '3'],
#  ['Joseph_Blatter', '1', '2'],
#  ['Joseph_Estrada', '2', '4'],
#  ['Juan_Carlos_Ferrero', '2', '9'],
#  ['Juan_Carlos_Ferrero', '7', '18'],
#  ['Juan_Ignacio_Chela', '1', '3'],
#  ['Juan_Pablo_Montoya', '3', '5'],
#  ['Juan_Valencia_Osorio', '1', '2'],
#  ['Juanes', '1', '2'],
#  ['Juanes', '1', '3'],
#  ['Juanes', '2', '3'],
#  ['Judy_Genshaft', '1', '2'],
#  ['Juergen_Peters', '1', '2'],
#  ['Julia_Tymoshenko', '1', '2'],
#  ['Julia_Tymoshenko', '1', '3'],
#  ['Julianne_Moore', '6', '12'],
#  ['Julianne_Moore', '9', '12'],
#  ['Julie_Taymor', '1', '2'],
#  ['Justin_Guarini', '1', '3'],
#  ['Justin_Guarini', '2', '3'],
#  ['Kate_Capshaw', '1', '2'],
#  ['Kate_Hudson', '2', '4'],
#  ['Kate_Winslet', '1', '4'],
#  ['Kate_Winslet', '2', '4'],
#  ['Katherine_Harris', '2', '3'],
#  ['Kathleen_Glynn', '1', '2'],
#  ['Kathryn_Bigelow', '1', '2'],
#  ['Katie_Harman', '2', '3'],
#  ['Keanu_Reeves', '2', '5'],
#  ['Keanu_Reeves', '2', '12'],
#  ['Keanu_Reeves', '4', '6'],
#  ['Kelli_White', '1', '2'],
#  ['Kelly_Clarkson', '1', '3'],
#  ['Kemal_Dervis', '1', '2'],
#  ['Ken_Watanabe', '1', '2'],
#  ['Kent_Rominger', '1', '2'],
#  ['Kevin_Spacey', '1', '5'],
#  ['Kevin_Spacey', '2', '4'],
#  ['Kevin_Stallings', '1', '2'],
#  ['Kim_Clijsters', '4', '9'],
#  ['Kim_Ryong-sung', '3', '10'],
#  ['Kim_Ryong-sung', '4', '6'],
#  ['Kim_Ryong-sung', '4', '9'],
#  ['Kimi_Raikkonen', '1', '3'],
#  ['Kimi_Raikkonen', '2', '3'],
#  ['Kobe_Bryant', '1', '3'],
#  ['Kobe_Bryant', '2', '3'],
#  ['Kurt_Busch', '1', '2'],
#  ['Kurt_Russell', '1', '2'],
#  ['Laila_Ali', '1', '2'],
#  ['Larry_Brown', '1', '2'],
#  ['Larry_Brown', '3', '7'],
#  ['Larry_Johnson', '1', '2'],
#  ['Larry_Lucchino', '1', '2'],
#  ['Lars_Von_Trier', '1', '3'],
#  ['Laura_Bush', '4', '32'],
#  ['Laura_Bush', '11', '40'],
#  ['Laura_Bush', '13', '16'],
#  ['Lauren_Hutton', '1', '2'],
#  ['LeAnn_Rimes', '1', '2'],
#  ['Leander_Paes', '1', '2'],
#  ['Lech_Walesa', '1', '2'],
#  ['Lee_Hoi-chang', '1', '3'],
#  ['Lee_Jun', '1', '2'],
#  ['Lee_Soo-hyuck', '1', '2'],
#  ['Lee_Soo-hyuck', '1', '3'],
#  ['Lee_Tae-sik', '1', '2'],
#  ['Lennox_Lewis', '2', '3'],
#  ['Lenny_Wilkens', '2', '3'],
#  ['Leonard_Hamilton', '1', '2'],
#  ['Lesley_McCulloch', '1', '2'],
#  ['Li_Peng', '1', '7'],
#  ['Li_Zhaoxing', '1', '3'],
#  ['Li_Zhaoxing', '1', '5'],
#  ['Li_Zhaoxing', '2', '8'],
#  ['Lim_Dong-won', '1', '2'],
#  ['Lionel_Richie', '1', '2'],
#  ['Lisa_Gottsegen', '1', '2'],
#  ['Lisa_Ling', '1', '2'],
#  ['Liu_Mingkang', '1', '2'],
#  ['Lleyton_Hewitt', '10', '12'],
#  ['Lon_Kruger', '1', '2'],
#  ['Lou_Piniella', '1', '3'],
#  ['Ludivine_Sagnier', '1', '4'],
#  ['Luiz_Inacio_Lula_da_Silva', '12', '33'],
#  ['Luiz_Inacio_Lula_da_Silva', '17', '42'],
#  ['Luiz_Inacio_Lula_da_Silva', '25', '33'],
#  ['Luke_Walton', '1', '2'],
#  ['Lynne_Cheney', '1', '3'],
#  ['Lynne_Cheney', '2', '3'],
#  ['Madonna', '2', '5'],
#  ['Magdalena_Maleeva', '1', '2'],
#  ['Mahathir_Mohamad', '9', '10'],
#  ['Mahathir_Mohamad', '11', '12'],
#  ['Manuel_Poggiali', '1', '2'],
#  ['Marc-Andre_Fleury', '1', '2'],
#  ['Marc_Grossman', '1', '2'],
#  ['Marc_Grossman', '1', '3'],
#  ['Marcelo_Ebrard', '1', '2'],
#  ['Marco_Antonio_Barrera', '3', '6'],
#  ['Marcus_Gronholm', '1', '2'],
#  ['Margaret_Thatcher', '1', '2'],
#  ['Maria_Luisa_Mendonca', '1', '2'],
#  ['Maria_Soledad_Alvear_Valenzuela', '1', '5'],
#  ['Maria_Soledad_Alvear_Valenzuela', '2', '3'],
#  ['Mariana_Pollack', '1', '2'],
#  ['Marie-Reine_Le_Gougne', '1', '2'],
#  ['Marilyn_Monroe', '1', '2'],
#  ['Marina_Anissina', '1', '2'],
#  ['Mark_Geragos', '1', '2'],
#  ['Mark_Gottfried', '1', '2'],
#  ['Mark_Hamister', '1', '2'],
#  ['Mark_Hurlbert', '2', '5'],
#  ['Mark_Schweiker', '1', '2'],
#  ['Mark_Warner', '1', '2'],
#  ['Martha_Beatriz_Roque', '1', '2'],
#  ['Martha_Bowen', '1', '2'],
#  ['Martha_Lucia_Ramirez', '2', '3'],
#  ['Martin_Brodeur', '1', '2'],
#  ['Martin_Hoellwarth', '1', '2'],
#  ['Martin_McCauley', '1', '2'],
#  ['Martin_Scorsese', '2', '6'],
#  ['Martin_Scorsese', '3', '6'],
#  ['Martin_Scorsese', '4', '5'],
#  ['Martina_Hingis', '1', '3'],
#  ['Martina_McBride', '2', '4'],
#  ['Martina_McBride', '3', '4'],
#  ['Marty_Mornhinweg', '2', '3'],
#  ['Mary-Kate_Olsen', '1', '2'],
#  ['Mary_Steenburgen', '2', '3'],
#  ['Masahiko_Nagasawa', '1', '2'],
#  ['Mathias_Reichhold', '1', '3'],
#  ['Matt_Damon', '1', '4'],
#  ['Matt_Damon', '2', '4'],
#  ['Matt_Damon', '3', '4'],
#  ['Matthew_Perry', '3', '5'],
#  ['Matthew_Perry', '3', '6'],
#  ['Matthew_Perry', '6', '7'],
#  ['Maureen_Fanning', '1', '2'],
#  ['Mel_Brooks', '1', '2'],
#  ['Mel_Gibson', '1', '2'],
#  ['Mesut_Yilmaz', '1', '2'],
#  ['Mian_Khursheed_Mehmood_Kasuri', '2', '3'],
#  ['Michael_Ballack', '1', '3'],
#  ['Michael_Ballack', '2', '3'],
#  ['Michael_Bloomberg', '1', '16'],
#  ['Michael_Caine', '1', '4'],
#  ['Michael_Caine', '2', '4'],
#  ['Michael_Chiklis', '2', '4'],
#  ['Michael_Douglas', '3', '5'],
#  ['Michael_Jordan', '1', '3'],
#  ['Michael_Jordan', '1', '4'],
#  ['Michael_Kostelnik', '1', '2'],
#  ['Michael_Moore', '1', '3'],
#  ['Michael_Patrick_King', '1', '2'],
#  ['Michael_Powell', '2', '4'],
#  ['Michael_Winterbottom', '1', '3'],
#  ['Michael_Winterbottom', '2', '3'],
#  ['Mick_Jagger', '2', '4'],
#  ['Miguel_Estrada', '1', '2'],
#  ['Mike_Babcock', '1', '2'],
#  ['Mike_Krzyzewski', '2', '4'],
#  ['Mike_Martz', '3', '5'],
#  ['Mike_Martz', '4', '5'],
#  ['Mike_Miller', '1', '2'],
#  ['Mike_Myers', '5', '7'],
#  ['Mike_Scioscia', '1', '2'],
#  ['Mike_Tyson', '1', '3'],
#  ['Mikhail_Kasyanov', '1', '2'],
#  ['Mikhail_Wehbe', '1', '4'],
#  ['Milo_Djukanovic', '1', '3'],
#  ['Milo_Maestrecampo', '1', '2'],
#  ['Milo_Maestrecampo', '1', '3'],
#  ['Milo_Maestrecampo', '2', '3'],
#  ['Miroljub', '1', '2'],
#  ['Miyako_Miyazaki', '1', '2'],
#  ['Mohamed_Benaissa', '1', '2'],
#  ['Mohammed_Al-Douri', '2', '5'],
#  ['Monica_Bellucci', '1', '3'],
#  ['Monica_Seles', '2', '3'],
#  ['Monica_Seles', '4', '6'],
#  ['Monique_Garbrecht-Enfeldt', '1', '3'],
#  ['Monique_Garbrecht-Enfeldt', '2', '3'],
#  ['Morgan_Freeman', '1', '2'],
#  ['Moshe_Katsav', '1', '4'],
#  ['Moshe_Katsav', '2', '3'],
#  ['Moshe_Katsav', '2', '4'],
#  ['Muhammad_Saeed_al-Sahhaf', '1', '5'],
#  ['Muhammad_Saeed_al-Sahhaf', '3', '4'],
#  ['Muhammad_Saeed_al-Sahhaf', '4', '5'],
#  ['Mukesh_Ambani', '1', '3'],
#  ['Munir_Akram', '1', '2'],
#  ['Nabil_Shaath', '1', '3'],
#  ['Nadia_Petrova', '1', '5'],
#  ['Naji_Sabri', '4', '8'],
#  ['Nancy_Demme', '1', '2'],
#  ['Nancy_Reagan', '1', '2'],
#  ['Nancy_Sinatra', '1', '2'],
#  ['Nanni_Moretti', '1', '2'],
#  ['Naomi_Watts', '12', '14'],
#  ['Natasha_McElhone', '2', '3'],
#  ['Nathalie_Baye', '1', '3'],
#  ['Nathalie_Baye', '2', '4'],
#  ['Nathan_Lane', '1', '2'],
#  ['Nebojsa_Pavkovic', '1', '2'],
#  ['Nia_Vardalos', '3', '4'],
#  ['Nicholas_Tse', '1', '2'],
#  ['Nick_Nolte', '1', '4'],
#  ['Nicolas_Cage', '1', '2'],
#  ['Nicolas_Escude', '1', '2'],
#  ['Nicolas_Lapentti', '1', '2'],
#  ['Noelle_Bush', '2', '4'],
#  ['Norah_Jones', '5', '13'],
#  ['Norman_Jewison', '1', '2'],
#  ['Norodom_Sihanouk', '1', '2'],
#  ['Norodom_Sihanouk', '2', '3'],
#  ['Nursultan_Nazarbayev', '1', '2'],
#  ['Oleksandr_Moroz', '1', '2'],
#  ['Olesya_Bonabarenko', '1', '2'],
#  ['Oswaldo_Paya', '3', '5'],
#  ['Oxana_Fedorova', '2', '4'],
#  ['Paradorn_Srichaphan', '3', '7'],
#  ['Paradorn_Srichaphan', '8', '10'],
#  ['Pascal_Lamy', '1', '2'],
#  ['Pat_Cox', '1', '2'],
#  ['Patricia_Clarkson', '1', '2'],
#  ['Patricia_Clarkson', '1', '3'],
#  ['Patricia_Heaton', '1', '2'],
#  ['Patrick_Ewing', '1', '2'],
#  ['Patrick_Roy', '1', '2'],
#  ['Patrick_Stewart', '1', '2'],
#  ['Paul_Coppin', '1', '2'],
#  ['Paul_McCartney', '4', '6'],
#  ['Paul_McNulty', '1', '2'],
#  ['Paul_ONeill', '8', '9'],
#  ['Paul_Pierce', '1', '2'],
#  ['Paul_Tagliabue', '1', '3'],
#  ['Paul_Tagliabue', '2', '3'],
#  ['Paul_Tagliabue', '2', '4'],
#  ['Paul_Wolfowitz', '2', '10'],
#  ['Paul_Wolfowitz', '3', '7'],
#  ['Paul_Wolfowitz', '3', '8'],
#  ['Paul_Wolfowitz', '5', '6'],
#  ['Paula_Radcliffe', '4', '5'],
#  ['Penelope_Ann_Miller', '1', '2'],
#  ['Pete_Carroll', '1', '2'],
#  ['Pete_Carroll', '2', '3'],
#  ['Pete_Sampras', '3', '18'],
#  ['Peter_Arnett', '2', '3'],
#  ['Peter_Bacanovic', '1', '2'],
#  ['Peter_Hillary', '1', '2'],
#  ['Peter_Struck', '1', '3'],
#  ['Peter_Struck', '1', '5'],
#  ['Petria_Thomas', '1', '2'],
#  ['Philippe_Noiret', '1', '2'],
#  ['Prince_Charles', '2', '4'],
#  ['Prince_Claus', '1', '3'],
#  ['Prince_Edward', '1', '2'],
#  ['Prince_Harry', '1', '2'],
#  ['Prince_Naruhito', '2', '3'],
#  ['Prince_William', '1', '2'],
#  ['Princess_Anne', '1', '2'],
#  ['Princess_Caroline', '1', '4'],
#  ['Princess_Elisabeth', '1', '2'],
#  ['Princess_Masako', '1', '2'],
#  ['Priscilla_Owen', '1', '2'],
#  ['Pupi_Avati', '2', '3'],
#  ['Queen_Beatrix', '1', '4'],
#  ['Queen_Beatrix', '2', '3'],
#  ['Queen_Elizabeth_II', '4', '11'],
#  ['Queen_Elizabeth_II', '5', '13'],
#  ['Queen_Elizabeth_II', '6', '7'],
#  ['Queen_Elizabeth_II', '6', '11'],
#  ['Queen_Latifah', '1', '3'],
#  ['Rainer_Schuettler', '1', '4'],
#  ['Rainer_Schuettler', '3', '4'],
#  ['Ralph_Lauren', '1', '2'],
#  ['Ranil_Wickremasinghe', '2', '3'],
#  ['Raoul_Ruiz', '1', '4'],
#  ['Raoul_Ruiz', '3', '4'],
#  ['Raquel_Welch', '1', '2'],
#  ['Ray_Allen', '1', '2'],
#  ['Ray_Allen', '2', '3'],
#  ['Raymond_Odierno', '1', '2'],
#  ['Rebekah_Chantay_Revels', '2', '4'],
#  ['Rebekah_Chantay_Revels', '3', '4'],
#  ['Recep_Tayyip_Erdogan', '2', '4'],
#  ['Recep_Tayyip_Erdogan', '2', '8'],
#  ['Recep_Tayyip_Erdogan', '14', '29'],
#  ['Reggie_Miller', '1', '2'],
#  ['Ricardo_Lagos', '1', '3'],
#  ['Ricardo_Lagos', '2', '23'],
#  ['Ricardo_Lagos', '9', '22'],
#  ['Ricardo_Lagos', '17', '18'],
#  ['Ricardo_Monasterio', '1', '2'],
#  ['Ricardo_Sanchez', '3', '4'],
#  ['Richard_Branson', '1', '2'],
#  ['Richard_Gephardt', '1', '3'],
#  ['Richard_Gephardt', '2', '6'],
#  ['Richard_Haass', '1', '2'],
#  ['Richard_Krajicek', '2', '3'],
#  ['Richard_Myers', '3', '4'],
#  ['Richard_Myers', '3', '14'],
#  ['Richard_Virenque', '3', '4'],
#  ['Rick_Barnes', '1', '2'],
#  ['Rick_Barnes', '1', '3'],
#  ['Rick_Santorum', '2', '3'],
#  ['Rick_Stansbury', '1', '2'],
#  ['Ricky_Martin', '1', '2'],
#  ['Rio_Ferdinand', '1', '2'],
#  ['Rob_Lowe', '1', '3'],
#  ['Rob_Lowe', '2', '3'],
#  ['Rob_Lowe', '3', '4'],
#  ['Rob_Marshall', '4', '6'],
#  ['Robbie_Williams', '1', '3'],
#  ['Robert_Blackwill', '1', '2'],
#  ['Robert_Bullock', '1', '2'],
#  ['Robert_De_Niro', '1', '2'],
#  ['Robert_De_Niro', '1', '6'],
#  ['Robert_De_Niro', '5', '6'],
#  ['Robert_Duvall', '1', '7'],
#  ['Robert_Duvall', '3', '6'],
#  ['Robert_Ehrlich', '1', '2'],
#  ['Robert_Fico', '1', '2'],
#  ['Robert_Kocharian', '3', '4'],
#  ['Robert_Mugabe', '1', '2'],
#  ['Robert_Stack', '1', '2'],
#  ['Robert_Witt', '1', '2'],
#  ['Robert_Zoellick', '2', '6'],
#  ['Roberto_Benigni', '1', '2'],
#  ['Roberto_Carlos', '1', '2'],
#  ['Robinson_Stevenin', '1', '2'],
#  ['Roger_Federer', '4', '8'],
#  ['Roger_Federer', '4', '12'],
#  ['Roger_Moore', '3', '5'],
#  ['Rogerio_Romero', '1', '2'],
#  ['Roh_Moo-hyun', '1', '31'],
#  ['Roh_Moo-hyun', '7', '15'],
#  ['Roman_Polanski', '2', '5'],
#  ['Roseanne_Barr', '1', '2'],
#  ['Roseanne_Barr', '1', '3'],
#  ['Ruben_Studdard', '1', '2'],
#  ['Rubens_Barrichello', '1', '9'],
#  ['Rubens_Barrichello', '2', '6'],
#  ['Rubens_Barrichello', '5', '10'],
#  ['Rudolph_Giuliani', '6', '17'],
#  ['Ruth_Dreifuss', '1', '2'],
#  ['Ruth_Harlow', '1', '2'],
#  ['Saburo_Kawabuchi', '1', '2'],
#  ['Sachiko_Yamada', '1', '4'],
#  ['Sachiko_Yamada', '2', '3'],
#  ['Sachiko_Yamada', '2', '4'],
#  ['Sachiko_Yamada', '3', '4'],
#  ['Sadie_Frost', '2', '3'],
#  ['Saeb_Erekat', '1', '2'],
#  ['Sally_Ride', '1', '2'],
#  ['Sam_Bith', '1', '2'],
#  ['Sam_Torrance', '2', '3'],
#  ['Samira_Makhmalbaf', '1', '2'],
#  ['Sammy_Sosa', '1', '2'],
#  ['Sandra_Bullock', '1', '4'],
#  ['Sandra_Bullock', '2', '4'],
#  ['Sandra_Bullock', '3', '4'],
#  ['Sarah_Hughes', '1', '2'],
#  ['Sarah_Hughes', '1', '6'],
#  ['Sarah_Michelle_Gellar', '2', '3'],
#  ['Scott_Peterson', '1', '3'],
#  ['Scott_Peterson', '4', '5'],
#  ['Scott_Wolf', '1', '2'],
#  ['Sean_Hayes', '1', '2'],
#  ['Sebastien_Grosjean', '1', '3'],
#  ['Sebastien_Grosjean', '2', '4'],
#  ['Sepp_Blatter', '1', '2'],
#  ['Sepp_Blatter', '3', '4'],
#  ['Serena_Williams', '17', '52'],
#  ['Sergei_Ivanov', '1', '5'],
#  ['Sergio_Garcia', '1', '2'],
#  ['Sergio_Vieira_De_Mello', '5', '6'],
#  ['Shane_Warne', '1', '2'],
#  ['Sharon_Davis', '1', '2'],
#  ['Sharon_Frey', '1', '2'],
#  ['Sheila_Copps', '1', '3'],
#  ['Sheila_Fraser', '1', '2'],
#  ['Sheryl_Crow', '3', '8'],
#  ['Shia_LaBeouf', '1', '2'],
#  ['Shimon_Peres', '2', '6'],
#  ['Sila_Calderon', '1', '3'],
#  ['Silvan_Shalom', '1', '6'],
#  ['Silvia_Farina_Elia', '1', '2'],
#  ['Silvia_Farina_Elia', '1', '3'],
#  ['Slobodan_Milosevic', '2', '3'],
#  ['Sonia_Gandhi', '1', '3'],
#  ['Sonia_Gandhi', '2', '3'],
#  ['Stacy_Dragila', '1', '2'],
#  ['Stephen_Daldry', '1', '2'],
#  ['Stephen_Friedman', '1', '2'],
#  ['Steve_Ballmer', '1', '2'],
#  ['Steve_Ballmer', '2', '3'],
#  ['Steve_Mariucci', '1', '2'],
#  ['Steve_Mariucci', '2', '3'],
#  ['Steve_Nash', '2', '4'],
#  ['Steve_Spurrier', '1', '2'],
#  ['Steve_Waugh', '1', '2'],
#  ['Steven_Spielberg', '1', '6'],
#  ['Stockard_Channing', '1', '3'],
#  ['Susan_Sarandon', '2', '3'],
#  ['Susan_Sarandon', '2', '6'],
#  ['Susan_Sarandon', '4', '6'],
#  ['Susilo_Bambang_Yudhoyono', '1', '2'],
#  ['Sylvester_Stallone', '1', '5'],
#  ['Takashi_Sorimachi', '1', '2'],
#  ...]

# %%
#funzione per estrarre le immagini delle coppie
def getImages(data_path, pairs):
    skipped_pairs = 0
    path_list = []
    is_same_list = []
    
    for pair in pairs:
        
        if len(pair) == 3: # allora sono della stessa persona
            path_first = os.path.join(data_path, pair[0], pair[0] + '_' + '%04d' % int(pair[1]) + '.jpg')
            path_second = os.path.join(data_path, pair[0], pair[0] + '_' + '%04d' % int(pair[2]) + '.jpg')
            is_same = True
            
        elif len(pair) == 4: # persone diverse
            path_first = os.path.join(data_path, pair[0], pair[0] + '_' + '%04d' % int(pair[1]) + '.jpg')
            path_first = os.path.join(data_path, pair[0], pair[0] + '_' + '%04d' % int(pair[3]) + '.jpg')
            is_same = False
            
        # verifico che entrambe le immagini esistano ai dati path
        if os.path.exists(path_first) and os.path.exists(path_second):
            path_list += (path_first, path_second)
            is_same_list.append(is_same)
        else:
            skipped_pairs += 1
    
    if skipped_pairs > 0:
        print(f"Pairs skipped: {skipped_pairs}")
    
    return path_list, is_same_list

# %%
getImages(data_path, pairs)
# Out:
# Pairs skipped: 172
# (['./LFW_DIR/Aaron_Peirsol/Aaron_Peirsol_0001.jpg',
#   './LFW_DIR/Aaron_Peirsol/Aaron_Peirsol_0002.jpg',
#   './LFW_DIR/Aaron_Peirsol/Aaron_Peirsol_0003.jpg',
#   './LFW_DIR/Aaron_Peirsol/Aaron_Peirsol_0004.jpg',
#   './LFW_DIR/Aaron_Sorkin/Aaron_Sorkin_0001.jpg',
#   './LFW_DIR/Aaron_Sorkin/Aaron_Sorkin_0002.jpg',
#   './LFW_DIR/Abdel_Nasser_Assidi/Abdel_Nasser_Assidi_0001.jpg',
#   './LFW_DIR/Abdel_Nasser_Assidi/Abdel_Nasser_Assidi_0002.jpg',
#   './LFW_DIR/Abdullah/Abdullah_0001.jpg',
#   './LFW_DIR/Abdullah/Abdullah_0003.jpg',
#   './LFW_DIR/Abdullah/Abdullah_0002.jpg',
#   './LFW_DIR/Abdullah/Abdullah_0004.jpg',
#   './LFW_DIR/Abdullah_al-Attiyah/Abdullah_al-Attiyah_0001.jpg',
#   './LFW_DIR/Abdullah_al-Attiyah/Abdullah_al-Attiyah_0003.jpg',
#   './LFW_DIR/Abdullah_al-Attiyah/Abdullah_al-Attiyah_0002.jpg',
#   './LFW_DIR/Abdullah_al-Attiyah/Abdullah_al-Attiyah_0003.jpg',
#   './LFW_DIR/Abel_Pacheco/Abel_Pacheco_0001.jpg',
#   './LFW_DIR/Abel_Pacheco/Abel_Pacheco_0004.jpg',
#   './LFW_DIR/Abel_Pacheco/Abel_Pacheco_0003.jpg',
#   './LFW_DIR/Abel_Pacheco/Abel_Pacheco_0004.jpg',
#   './LFW_DIR/Adam_Sandler/Adam_Sandler_0001.jpg',
#   './LFW_DIR/Adam_Sandler/Adam_Sandler_0003.jpg',
#   './LFW_DIR/Adam_Sandler/Adam_Sandler_0001.jpg',
#   './LFW_DIR/Adam_Sandler/Adam_Sandler_0004.jpg',
#   './LFW_DIR/Adam_Sandler/Adam_Sandler_0002.jpg',
#   './LFW_DIR/Adam_Sandler/Adam_Sandler_0004.jpg',
#   './LFW_DIR/Adam_Scott/Adam_Scott_0001.jpg',
#   './LFW_DIR/Adam_Scott/Adam_Scott_0002.jpg',
#   './LFW_DIR/Adolfo_Aguilar_Zinser/Adolfo_Aguilar_Zinser_0001.jpg',
#   './LFW_DIR/Adolfo_Aguilar_Zinser/Adolfo_Aguilar_Zinser_0003.jpg',
#   './LFW_DIR/Ahmed_Chalabi/Ahmed_Chalabi_0002.jpg',
#   './LFW_DIR/Ahmed_Chalabi/Ahmed_Chalabi_0004.jpg',
#   './LFW_DIR/Ai_Sugiyama/Ai_Sugiyama_0002.jpg',
#   './LFW_DIR/Ai_Sugiyama/Ai_Sugiyama_0004.jpg',
#   './LFW_DIR/Aicha_El_Ouafi/Aicha_El_Ouafi_0001.jpg',
#   './LFW_DIR/Aicha_El_Ouafi/Aicha_El_Ouafi_0003.jpg',
#   './LFW_DIR/Aicha_El_Ouafi/Aicha_El_Ouafi_0002.jpg',
#   './LFW_DIR/Aicha_El_Ouafi/Aicha_El_Ouafi_0003.jpg',
#   './LFW_DIR/Akbar_Hashemi_Rafsanjani/Akbar_Hashemi_Rafsanjani_0001.jpg',
#   './LFW_DIR/Akbar_Hashemi_Rafsanjani/Akbar_Hashemi_Rafsanjani_0003.jpg',
#   './LFW_DIR/Akhmed_Zakayev/Akhmed_Zakayev_0001.jpg',
#   './LFW_DIR/Akhmed_Zakayev/Akhmed_Zakayev_0003.jpg',
#   './LFW_DIR/Akhmed_Zakayev/Akhmed_Zakayev_0002.jpg',
#   './LFW_DIR/Akhmed_Zakayev/Akhmed_Zakayev_0003.jpg',
#   './LFW_DIR/Al_Gore/Al_Gore_0001.jpg',
#   './LFW_DIR/Al_Gore/Al_Gore_0003.jpg',
#   './LFW_DIR/Alan_Ball/Alan_Ball_0001.jpg',
#   './LFW_DIR/Alan_Ball/Alan_Ball_0002.jpg',
#   './LFW_DIR/Alberto_Fujimori/Alberto_Fujimori_0001.jpg',
#   './LFW_DIR/Alberto_Fujimori/Alberto_Fujimori_0002.jpg',
#   './LFW_DIR/Alberto_Ruiz_Gallardon/Alberto_Ruiz_Gallardon_0001.jpg',
#   './LFW_DIR/Alberto_Ruiz_Gallardon/Alberto_Ruiz_Gallardon_0002.jpg',
#   './LFW_DIR/Albrecht_Mentz/Albrecht_Mentz_0001.jpg',
#   './LFW_DIR/Albrecht_Mentz/Albrecht_Mentz_0002.jpg',
#   './LFW_DIR/Alec_Baldwin/Alec_Baldwin_0001.jpg',
#   './LFW_DIR/Alec_Baldwin/Alec_Baldwin_0002.jpg',
#   './LFW_DIR/Alec_Baldwin/Alec_Baldwin_0001.jpg',
#   './LFW_DIR/Alec_Baldwin/Alec_Baldwin_0004.jpg',
#   './LFW_DIR/Alec_Baldwin/Alec_Baldwin_0002.jpg',
#   './LFW_DIR/Alec_Baldwin/Alec_Baldwin_0003.jpg',
#   './LFW_DIR/Alec_Baldwin/Alec_Baldwin_0003.jpg',
#   './LFW_DIR/Alec_Baldwin/Alec_Baldwin_0004.jpg',
#   './LFW_DIR/Alejandro_Toledo/Alejandro_Toledo_0020.jpg',
#   './LFW_DIR/Alejandro_Toledo/Alejandro_Toledo_0038.jpg',
#   './LFW_DIR/Alex_Barros/Alex_Barros_0001.jpg',
#   './LFW_DIR/Alex_Barros/Alex_Barros_0002.jpg',
#   './LFW_DIR/Alex_Sink/Alex_Sink_0002.jpg',
#   './LFW_DIR/Alex_Sink/Alex_Sink_0003.jpg',
#   './LFW_DIR/Alexandra_Stevenson/Alexandra_Stevenson_0001.jpg',
#   './LFW_DIR/Alexandra_Stevenson/Alexandra_Stevenson_0002.jpg',
#   './LFW_DIR/Alexandra_Stevenson/Alexandra_Stevenson_0001.jpg',
#   './LFW_DIR/Alexandra_Stevenson/Alexandra_Stevenson_0003.jpg',
#   './LFW_DIR/Alexandra_Vodjanikova/Alexandra_Vodjanikova_0001.jpg',
#   './LFW_DIR/Alexandra_Vodjanikova/Alexandra_Vodjanikova_0002.jpg',
#   './LFW_DIR/Ali_Abbas/Ali_Abbas_0001.jpg',
#   './LFW_DIR/Ali_Abbas/Ali_Abbas_0002.jpg',
#   './LFW_DIR/Ali_Khamenei/Ali_Khamenei_0001.jpg',
#   './LFW_DIR/Ali_Khamenei/Ali_Khamenei_0002.jpg',
#   './LFW_DIR/Alice_Fisher/Alice_Fisher_0001.jpg',
#   './LFW_DIR/Alice_Fisher/Alice_Fisher_0002.jpg',
#   './LFW_DIR/Alicia_Silverstone/Alicia_Silverstone_0001.jpg',
#   './LFW_DIR/Alicia_Silverstone/Alicia_Silverstone_0002.jpg',
#   './LFW_DIR/Alimzhan_Tokhtakhounov/Alimzhan_Tokhtakhounov_0001.jpg',
#   './LFW_DIR/Alimzhan_Tokhtakhounov/Alimzhan_Tokhtakhounov_0002.jpg',
#   './LFW_DIR/Alison_Lohman/Alison_Lohman_0001.jpg',
#   './LFW_DIR/Alison_Lohman/Alison_Lohman_0002.jpg',
#   './LFW_DIR/Alvaro_Noboa/Alvaro_Noboa_0001.jpg',
#   './LFW_DIR/Alvaro_Noboa/Alvaro_Noboa_0002.jpg',
#   './LFW_DIR/Alvaro_Noboa/Alvaro_Noboa_0002.jpg',
#   './LFW_DIR/Alvaro_Noboa/Alvaro_Noboa_0003.jpg',
#   './LFW_DIR/Alvaro_Silva_Calderon/Alvaro_Silva_Calderon_0003.jpg',
#   './LFW_DIR/Alvaro_Silva_Calderon/Alvaro_Silva_Calderon_0004.jpg',
#   './LFW_DIR/Amanda_Beard/Amanda_Beard_0001.jpg',
#   './LFW_DIR/Amanda_Beard/Amanda_Beard_0002.jpg',
#   './LFW_DIR/Amber_Tamblyn/Amber_Tamblyn_0001.jpg',
#   './LFW_DIR/Amber_Tamblyn/Amber_Tamblyn_0002.jpg',
#   './LFW_DIR/Amelia_Vega/Amelia_Vega_0002.jpg',
#   './LFW_DIR/Amelia_Vega/Amelia_Vega_0004.jpg',
#   './LFW_DIR/Amelia_Vega/Amelia_Vega_0005.jpg',
#   './LFW_DIR/Amelia_Vega/Amelia_Vega_0007.jpg',
#   './LFW_DIR/Amelia_Vega/Amelia_Vega_0006.jpg',
#   './LFW_DIR/Amelia_Vega/Amelia_Vega_0007.jpg',
#   './LFW_DIR/Amer_al-Saadi/Amer_al-Saadi_0001.jpg',
#   './LFW_DIR/Amer_al-Saadi/Amer_al-Saadi_0002.jpg',
#   './LFW_DIR/Ana_Guevara/Ana_Guevara_0001.jpg',
#   './LFW_DIR/Ana_Guevara/Ana_Guevara_0005.jpg',
#   './LFW_DIR/Ana_Guevara/Ana_Guevara_0001.jpg',
#   './LFW_DIR/Ana_Guevara/Ana_Guevara_0006.jpg',
#   './LFW_DIR/Ana_Guevara/Ana_Guevara_0002.jpg',
#   './LFW_DIR/Ana_Guevara/Ana_Guevara_0006.jpg',
#   './LFW_DIR/Ana_Guevara/Ana_Guevara_0003.jpg',
#   './LFW_DIR/Ana_Guevara/Ana_Guevara_0006.jpg',
#   './LFW_DIR/Anastasia_Myskina/Anastasia_Myskina_0001.jpg',
#   './LFW_DIR/Anastasia_Myskina/Anastasia_Myskina_0002.jpg',
#   './LFW_DIR/Anastasia_Myskina/Anastasia_Myskina_0002.jpg',
#   './LFW_DIR/Anastasia_Myskina/Anastasia_Myskina_0003.jpg',
#   './LFW_DIR/Anders_Fogh_Rasmussen/Anders_Fogh_Rasmussen_0001.jpg',
#   './LFW_DIR/Anders_Fogh_Rasmussen/Anders_Fogh_Rasmussen_0002.jpg',
#   './LFW_DIR/Anders_Fogh_Rasmussen/Anders_Fogh_Rasmussen_0003.jpg',
#   './LFW_DIR/Anders_Fogh_Rasmussen/Anders_Fogh_Rasmussen_0004.jpg',
#   './LFW_DIR/Andre_Agassi/Andre_Agassi_0009.jpg',
#   './LFW_DIR/Andre_Agassi/Andre_Agassi_0018.jpg',
#   './LFW_DIR/Andrew_Weissmann/Andrew_Weissmann_0001.jpg',
#   './LFW_DIR/Andrew_Weissmann/Andrew_Weissmann_0003.jpg',
#   './LFW_DIR/Andy_Roddick/Andy_Roddick_0003.jpg',
#   './LFW_DIR/Andy_Roddick/Andy_Roddick_0015.jpg',
#   './LFW_DIR/Andy_Roddick/Andy_Roddick_0009.jpg',
#   './LFW_DIR/Andy_Roddick/Andy_Roddick_0014.jpg',
#   './LFW_DIR/Andy_Roddick/Andy_Roddick_0012.jpg',
#   './LFW_DIR/Andy_Roddick/Andy_Roddick_0015.jpg',
#   './LFW_DIR/Angela_Bassett/Angela_Bassett_0002.jpg',
#   './LFW_DIR/Angela_Bassett/Angela_Bassett_0006.jpg',
#   './LFW_DIR/Angelina_Jolie/Angelina_Jolie_0003.jpg',
#   './LFW_DIR/Angelina_Jolie/Angelina_Jolie_0015.jpg',
#   './LFW_DIR/Angelina_Jolie/Angelina_Jolie_0004.jpg',
#   './LFW_DIR/Angelina_Jolie/Angelina_Jolie_0016.jpg',
#   './LFW_DIR/Angelina_Jolie/Angelina_Jolie_0008.jpg',
#   './LFW_DIR/Angelina_Jolie/Angelina_Jolie_0015.jpg',
#   './LFW_DIR/Angelina_Jolie/Angelina_Jolie_0009.jpg',
#   './LFW_DIR/Angelina_Jolie/Angelina_Jolie_0017.jpg',
#   './LFW_DIR/Angelina_Jolie/Angelina_Jolie_0016.jpg',
#   './LFW_DIR/Angelina_Jolie/Angelina_Jolie_0017.jpg',
#   './LFW_DIR/Anibal_Ibarra/Anibal_Ibarra_0002.jpg',
#   './LFW_DIR/Anibal_Ibarra/Anibal_Ibarra_0003.jpg',
#   './LFW_DIR/Anna_Kournikova/Anna_Kournikova_0005.jpg',
#   './LFW_DIR/Anna_Kournikova/Anna_Kournikova_0009.jpg',
#   './LFW_DIR/Annette_Bening/Annette_Bening_0001.jpg',
#   './LFW_DIR/Annette_Bening/Annette_Bening_0002.jpg',
#   './LFW_DIR/Anthony_Hopkins/Anthony_Hopkins_0001.jpg',
#   './LFW_DIR/Anthony_Hopkins/Anthony_Hopkins_0002.jpg',
#   './LFW_DIR/Antonio_Banderas/Antonio_Banderas_0002.jpg',
#   './LFW_DIR/Antonio_Banderas/Antonio_Banderas_0003.jpg',
#   './LFW_DIR/Antonio_Banderas/Antonio_Banderas_0002.jpg',
#   './LFW_DIR/Antonio_Banderas/Antonio_Banderas_0004.jpg',
#   './LFW_DIR/Antony_Leung/Antony_Leung_0002.jpg',
#   './LFW_DIR/Antony_Leung/Antony_Leung_0003.jpg',
#   './LFW_DIR/Anwar_Ibrahim/Anwar_Ibrahim_0001.jpg',
#   './LFW_DIR/Anwar_Ibrahim/Anwar_Ibrahim_0002.jpg',
#   './LFW_DIR/Arantxa_Sanchez-Vicario/Arantxa_Sanchez-Vicario_0001.jpg',
#   './LFW_DIR/Arantxa_Sanchez-Vicario/Arantxa_Sanchez-Vicario_0002.jpg',
#   './LFW_DIR/Ari_Fleischer/Ari_Fleischer_0001.jpg',
#   './LFW_DIR/Ari_Fleischer/Ari_Fleischer_0013.jpg',
#   './LFW_DIR/Ari_Fleischer/Ari_Fleischer_0002.jpg',
#   './LFW_DIR/Ari_Fleischer/Ari_Fleischer_0004.jpg',
#   './LFW_DIR/Ari_Fleischer/Ari_Fleischer_0004.jpg',
#   './LFW_DIR/Ari_Fleischer/Ari_Fleischer_0006.jpg',
#   './LFW_DIR/Ari_Fleischer/Ari_Fleischer_0008.jpg',
#   './LFW_DIR/Ari_Fleischer/Ari_Fleischer_0013.jpg',
#   './LFW_DIR/Arianna_Huffington/Arianna_Huffington_0001.jpg',
#   './LFW_DIR/Arianna_Huffington/Arianna_Huffington_0002.jpg',
#   './LFW_DIR/Arianna_Huffington/Arianna_Huffington_0002.jpg',
#   './LFW_DIR/Arianna_Huffington/Arianna_Huffington_0003.jpg',
#   './LFW_DIR/Arminio_Fraga/Arminio_Fraga_0002.jpg',
#   './LFW_DIR/Arminio_Fraga/Arminio_Fraga_0006.jpg',
#   './LFW_DIR/Arnold_Palmer/Arnold_Palmer_0001.jpg',
#   './LFW_DIR/Arnold_Palmer/Arnold_Palmer_0002.jpg',
#   './LFW_DIR/Arnold_Palmer/Arnold_Palmer_0001.jpg',
#   './LFW_DIR/Arnold_Palmer/Arnold_Palmer_0003.jpg',
#   './LFW_DIR/Arnoldo_Aleman/Arnoldo_Aleman_0001.jpg',
#   './LFW_DIR/Arnoldo_Aleman/Arnoldo_Aleman_0003.jpg',
#   './LFW_DIR/Arnoldo_Aleman/Arnoldo_Aleman_0002.jpg',
#   './LFW_DIR/Arnoldo_Aleman/Arnoldo_Aleman_0004.jpg',
#   './LFW_DIR/Aron_Ralston/Aron_Ralston_0001.jpg',
#   './LFW_DIR/Aron_Ralston/Aron_Ralston_0002.jpg',
#   './LFW_DIR/Art_Hoffmann/Art_Hoffmann_0001.jpg',
#   './LFW_DIR/Art_Hoffmann/Art_Hoffmann_0002.jpg',
#   './LFW_DIR/Arturo_Gatti/Arturo_Gatti_0001.jpg',
#   './LFW_DIR/Arturo_Gatti/Arturo_Gatti_0002.jpg',
#   './LFW_DIR/Arturo_Gatti/Arturo_Gatti_0002.jpg',
#   './LFW_DIR/Arturo_Gatti/Arturo_Gatti_0003.jpg',
#   './LFW_DIR/Arye_Mekel/Arye_Mekel_0001.jpg',
#   './LFW_DIR/Arye_Mekel/Arye_Mekel_0002.jpg',
#   './LFW_DIR/Asa_Hutchinson/Asa_Hutchinson_0001.jpg',
#   './LFW_DIR/Asa_Hutchinson/Asa_Hutchinson_0002.jpg',
#   './LFW_DIR/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0010.jpg',
#   './LFW_DIR/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0020.jpg',
#   './LFW_DIR/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0017.jpg',
#   './LFW_DIR/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0024.jpg',
#   './LFW_DIR/Augusto_Roa_Bastos/Augusto_Roa_Bastos_0001.jpg',
#   './LFW_DIR/Augusto_Roa_Bastos/Augusto_Roa_Bastos_0002.jpg',
#   './LFW_DIR/Azra_Akin/Azra_Akin_0001.jpg',
#   './LFW_DIR/Azra_Akin/Azra_Akin_0004.jpg',
#   './LFW_DIR/Barbara_Walters/Barbara_Walters_0001.jpg',
#   './LFW_DIR/Barbara_Walters/Barbara_Walters_0003.jpg',
#   './LFW_DIR/Barbara_Walters/Barbara_Walters_0001.jpg',
#   './LFW_DIR/Barbara_Walters/Barbara_Walters_0004.jpg',
#   './LFW_DIR/Barbara_Walters/Barbara_Walters_0003.jpg',
#   './LFW_DIR/Barbara_Walters/Barbara_Walters_0004.jpg',
#   './LFW_DIR/Barbra_Streisand/Barbra_Streisand_0001.jpg',
#   './LFW_DIR/Barbra_Streisand/Barbra_Streisand_0002.jpg',
#   './LFW_DIR/Barbra_Streisand/Barbra_Streisand_0002.jpg',
#   './LFW_DIR/Barbra_Streisand/Barbra_Streisand_0003.jpg',
#   './LFW_DIR/Barrett_Jackman/Barrett_Jackman_0001.jpg',
#   './LFW_DIR/Barrett_Jackman/Barrett_Jackman_0002.jpg',
#   './LFW_DIR/Barry_Zito/Barry_Zito_0001.jpg',
#   './LFW_DIR/Barry_Zito/Barry_Zito_0002.jpg',
#   './LFW_DIR/Bashar_Assad/Bashar_Assad_0001.jpg',
#   './LFW_DIR/Bashar_Assad/Bashar_Assad_0003.jpg',
#   './LFW_DIR/Bashar_Assad/Bashar_Assad_0003.jpg',
#   './LFW_DIR/Bashar_Assad/Bashar_Assad_0004.jpg',
#   './LFW_DIR/Ben_Glisan/Ben_Glisan_0001.jpg',
#   './LFW_DIR/Ben_Glisan/Ben_Glisan_0002.jpg',
#   './LFW_DIR/Ben_Howland/Ben_Howland_0001.jpg',
#   './LFW_DIR/Ben_Howland/Ben_Howland_0002.jpg',
#   './LFW_DIR/Benazir_Bhutto/Benazir_Bhutto_0001.jpg',
#   './LFW_DIR/Benazir_Bhutto/Benazir_Bhutto_0002.jpg',
#   './LFW_DIR/Benazir_Bhutto/Benazir_Bhutto_0002.jpg',
#   './LFW_DIR/Benazir_Bhutto/Benazir_Bhutto_0005.jpg',
#   './LFW_DIR/Bernard_Landry/Bernard_Landry_0001.jpg',
#   './LFW_DIR/Bernard_Landry/Bernard_Landry_0002.jpg',
#   './LFW_DIR/Bernard_Landry/Bernard_Landry_0001.jpg',
#   './LFW_DIR/Bernard_Landry/Bernard_Landry_0004.jpg',
#   './LFW_DIR/Bernard_Law/Bernard_Law_0001.jpg',
#   './LFW_DIR/Bernard_Law/Bernard_Law_0002.jpg',
#   './LFW_DIR/Bernard_Law/Bernard_Law_0002.jpg',
#   './LFW_DIR/Bernard_Law/Bernard_Law_0005.jpg',
#   './LFW_DIR/Bernardo_Segura/Bernardo_Segura_0001.jpg',
#   './LFW_DIR/Bernardo_Segura/Bernardo_Segura_0002.jpg',
#   './LFW_DIR/Beth_Jones/Beth_Jones_0001.jpg',
#   './LFW_DIR/Beth_Jones/Beth_Jones_0002.jpg',
#   './LFW_DIR/Bijan_Darvish/Bijan_Darvish_0001.jpg',
#   './LFW_DIR/Bijan_Darvish/Bijan_Darvish_0003.jpg',
#   './LFW_DIR/Bijan_Namdar_Zangeneh/Bijan_Namdar_Zangeneh_0001.jpg',
#   './LFW_DIR/Bijan_Namdar_Zangeneh/Bijan_Namdar_Zangeneh_0002.jpg',
#   './LFW_DIR/Bill_Belichick/Bill_Belichick_0001.jpg',
#   './LFW_DIR/Bill_Belichick/Bill_Belichick_0002.jpg',
#   './LFW_DIR/Bill_Callahan/Bill_Callahan_0001.jpg',
#   './LFW_DIR/Bill_Callahan/Bill_Callahan_0002.jpg',
#   './LFW_DIR/Bill_Callahan/Bill_Callahan_0001.jpg',
#   './LFW_DIR/Bill_Callahan/Bill_Callahan_0003.jpg',
#   './LFW_DIR/Bill_Clinton/Bill_Clinton_0004.jpg',
#   './LFW_DIR/Bill_Clinton/Bill_Clinton_0020.jpg',
#   './LFW_DIR/Bill_Gates/Bill_Gates_0003.jpg',
#   './LFW_DIR/Bill_Gates/Bill_Gates_0011.jpg',
#   './LFW_DIR/Bill_Gates/Bill_Gates_0004.jpg',
#   './LFW_DIR/Bill_Gates/Bill_Gates_0015.jpg',
#   './LFW_DIR/Bill_Graham/Bill_Graham_0001.jpg',
#   './LFW_DIR/Bill_Graham/Bill_Graham_0007.jpg',
#   './LFW_DIR/Bill_Graham/Bill_Graham_0008.jpg',
#   './LFW_DIR/Bill_Graham/Bill_Graham_0009.jpg',
#   './LFW_DIR/Bill_Nelson/Bill_Nelson_0001.jpg',
#   './LFW_DIR/Bill_Nelson/Bill_Nelson_0002.jpg',
#   './LFW_DIR/Bill_Simon/Bill_Simon_0004.jpg',
#   './LFW_DIR/Bill_Simon/Bill_Simon_0015.jpg',
#   './LFW_DIR/Bill_Simon/Bill_Simon_0005.jpg',
#   './LFW_DIR/Bill_Simon/Bill_Simon_0013.jpg',
#   './LFW_DIR/Billy_Crystal/Billy_Crystal_0003.jpg',
#   './LFW_DIR/Billy_Crystal/Billy_Crystal_0005.jpg',
#   './LFW_DIR/Billy_Crystal/Billy_Crystal_0003.jpg',
#   './LFW_DIR/Billy_Crystal/Billy_Crystal_0006.jpg',
#   './LFW_DIR/Billy_Crystal/Billy_Crystal_0005.jpg',
#   './LFW_DIR/Billy_Crystal/Billy_Crystal_0006.jpg',
#   './LFW_DIR/Billy_Graham/Billy_Graham_0001.jpg',
#   './LFW_DIR/Billy_Graham/Billy_Graham_0002.jpg',
#   './LFW_DIR/Binyamin_Ben-Eliezer/Binyamin_Ben-Eliezer_0002.jpg',
#   './LFW_DIR/Binyamin_Ben-Eliezer/Binyamin_Ben-Eliezer_0005.jpg',
#   './LFW_DIR/Binyamin_Ben-Eliezer/Binyamin_Ben-Eliezer_0003.jpg',
#   './LFW_DIR/Binyamin_Ben-Eliezer/Binyamin_Ben-Eliezer_0007.jpg',
#   './LFW_DIR/Bo_Ryan/Bo_Ryan_0001.jpg',
#   './LFW_DIR/Bo_Ryan/Bo_Ryan_0002.jpg',
#   './LFW_DIR/Bob_Beauprez/Bob_Beauprez_0001.jpg',
#   './LFW_DIR/Bob_Beauprez/Bob_Beauprez_0002.jpg',
#   './LFW_DIR/Bob_Geldof/Bob_Geldof_0001.jpg',
#   './LFW_DIR/Bob_Geldof/Bob_Geldof_0002.jpg',
#   './LFW_DIR/Bob_Graham/Bob_Graham_0001.jpg',
#   './LFW_DIR/Bob_Graham/Bob_Graham_0005.jpg',
#   './LFW_DIR/Bob_Graham/Bob_Graham_0001.jpg',
#   './LFW_DIR/Bob_Graham/Bob_Graham_0006.jpg',
#   './LFW_DIR/Bob_Graham/Bob_Graham_0002.jpg',
#   './LFW_DIR/Bob_Graham/Bob_Graham_0004.jpg',
#   './LFW_DIR/Bob_Graham/Bob_Graham_0003.jpg',
#   './LFW_DIR/Bob_Graham/Bob_Graham_0005.jpg',
#   './LFW_DIR/Bob_Huggins/Bob_Huggins_0001.jpg',
#   './LFW_DIR/Bob_Huggins/Bob_Huggins_0002.jpg',
#   './LFW_DIR/Bob_Stoops/Bob_Stoops_0005.jpg',
#   './LFW_DIR/Bob_Stoops/Bob_Stoops_0007.jpg',
#   './LFW_DIR/Bobby_Robson/Bobby_Robson_0001.jpg',
#   './LFW_DIR/Bobby_Robson/Bobby_Robson_0002.jpg',
#   './LFW_DIR/Boris_Berezovsky/Boris_Berezovsky_0001.jpg',
#   './LFW_DIR/Boris_Berezovsky/Boris_Berezovsky_0002.jpg',
#   './LFW_DIR/Branko_Crvenkovski/Branko_Crvenkovski_0001.jpg',
#   './LFW_DIR/Branko_Crvenkovski/Branko_Crvenkovski_0003.jpg',
#   './LFW_DIR/Brendan_Hansen/Brendan_Hansen_0001.jpg',
#   './LFW_DIR/Brendan_Hansen/Brendan_Hansen_0002.jpg',
#   './LFW_DIR/Brooke_Shields/Brooke_Shields_0001.jpg',
#   './LFW_DIR/Brooke_Shields/Brooke_Shields_0002.jpg',
#   './LFW_DIR/Bruce_Van_De_Velde/Bruce_Van_De_Velde_0001.jpg',
#   './LFW_DIR/Bruce_Van_De_Velde/Bruce_Van_De_Velde_0002.jpg',
#   './LFW_DIR/Bruce_Weber/Bruce_Weber_0001.jpg',
#   './LFW_DIR/Bruce_Weber/Bruce_Weber_0002.jpg',
#   './LFW_DIR/Bud_Selig/Bud_Selig_0001.jpg',
#   './LFW_DIR/Bud_Selig/Bud_Selig_0002.jpg',
#   './LFW_DIR/Bud_Selig/Bud_Selig_0001.jpg',
#   './LFW_DIR/Bud_Selig/Bud_Selig_0004.jpg',
#   './LFW_DIR/Bulent_Ecevit/Bulent_Ecevit_0002.jpg',
#   './LFW_DIR/Bulent_Ecevit/Bulent_Ecevit_0004.jpg',
#   './LFW_DIR/Bulent_Ecevit/Bulent_Ecevit_0002.jpg',
#   './LFW_DIR/Bulent_Ecevit/Bulent_Ecevit_0005.jpg',
#   './LFW_DIR/Bulent_Ecevit/Bulent_Ecevit_0003.jpg',
#   './LFW_DIR/Bulent_Ecevit/Bulent_Ecevit_0006.jpg',
#   './LFW_DIR/Cameron_Diaz/Cameron_Diaz_0003.jpg',
#   './LFW_DIR/Cameron_Diaz/Cameron_Diaz_0004.jpg',
#   './LFW_DIR/Candie_Kung/Candie_Kung_0001.jpg',
#   './LFW_DIR/Candie_Kung/Candie_Kung_0002.jpg',
#   './LFW_DIR/Candie_Kung/Candie_Kung_0002.jpg',
#   './LFW_DIR/Candie_Kung/Candie_Kung_0003.jpg',
#   './LFW_DIR/Carla_Myers/Carla_Myers_0001.jpg',
#   './LFW_DIR/Carla_Myers/Carla_Myers_0002.jpg',
#   './LFW_DIR/Carlos_Menem/Carlos_Menem_0001.jpg',
#   './LFW_DIR/Carlos_Menem/Carlos_Menem_0003.jpg',
#   './LFW_DIR/Carlos_Menem/Carlos_Menem_0006.jpg',
#   './LFW_DIR/Carlos_Menem/Carlos_Menem_0012.jpg',
#   './LFW_DIR/Carlos_Ruiz/Carlos_Ruiz_0002.jpg',
#   './LFW_DIR/Carlos_Ruiz/Carlos_Ruiz_0003.jpg',
#   './LFW_DIR/Carlos_Vives/Carlos_Vives_0001.jpg',
#   './LFW_DIR/Carlos_Vives/Carlos_Vives_0002.jpg',
#   './LFW_DIR/Carlos_Vives/Carlos_Vives_0002.jpg',
#   './LFW_DIR/Carlos_Vives/Carlos_Vives_0003.jpg',
#   './LFW_DIR/Carly_Fiorina/Carly_Fiorina_0001.jpg',
#   './LFW_DIR/Carly_Fiorina/Carly_Fiorina_0002.jpg',
#   './LFW_DIR/Carly_Fiorina/Carly_Fiorina_0001.jpg',
#   './LFW_DIR/Carly_Fiorina/Carly_Fiorina_0003.jpg',
#   './LFW_DIR/Carmen_Electra/Carmen_Electra_0001.jpg',
#   './LFW_DIR/Carmen_Electra/Carmen_Electra_0006.jpg',
#   './LFW_DIR/Carol_Moseley_Braun/Carol_Moseley_Braun_0001.jpg',
#   './LFW_DIR/Carol_Moseley_Braun/Carol_Moseley_Braun_0002.jpg',
#   './LFW_DIR/Carolina_Kluft/Carolina_Kluft_0001.jpg',
#   './LFW_DIR/Carolina_Kluft/Carolina_Kluft_0003.jpg',
#   './LFW_DIR/Caroline_Kennedy/Caroline_Kennedy_0001.jpg',
#   './LFW_DIR/Caroline_Kennedy/Caroline_Kennedy_0003.jpg',
#   './LFW_DIR/Carson_Palmer/Carson_Palmer_0002.jpg',
#   './LFW_DIR/Carson_Palmer/Carson_Palmer_0004.jpg',
#   './LFW_DIR/Cate_Blanchett/Cate_Blanchett_0002.jpg',
#   './LFW_DIR/Cate_Blanchett/Cate_Blanchett_0003.jpg',
#   './LFW_DIR/Cate_Blanchett/Cate_Blanchett_0002.jpg',
#   './LFW_DIR/Cate_Blanchett/Cate_Blanchett_0004.jpg',
#   './LFW_DIR/Catherine_Deneuve/Catherine_Deneuve_0002.jpg',
#   './LFW_DIR/Catherine_Deneuve/Catherine_Deneuve_0005.jpg',
#   './LFW_DIR/Catherine_Zeta-Jones/Catherine_Zeta-Jones_0001.jpg',
#   './LFW_DIR/Catherine_Zeta-Jones/Catherine_Zeta-Jones_0004.jpg',
#   './LFW_DIR/Catherine_Zeta-Jones/Catherine_Zeta-Jones_0001.jpg',
#   './LFW_DIR/Catherine_Zeta-Jones/Catherine_Zeta-Jones_0008.jpg',
#   './LFW_DIR/Catherine_Zeta-Jones/Catherine_Zeta-Jones_0004.jpg',
#   './LFW_DIR/Catherine_Zeta-Jones/Catherine_Zeta-Jones_0009.jpg',
#   './LFW_DIR/Catherine_Zeta-Jones/Catherine_Zeta-Jones_0006.jpg',
#   './LFW_DIR/Catherine_Zeta-Jones/Catherine_Zeta-Jones_0009.jpg',
#   './LFW_DIR/Catherine_Zeta-Jones/Catherine_Zeta-Jones_0008.jpg',
#   './LFW_DIR/Catherine_Zeta-Jones/Catherine_Zeta-Jones_0010.jpg',
#   './LFW_DIR/Cecilia_Bolocco/Cecilia_Bolocco_0001.jpg',
#   './LFW_DIR/Cecilia_Bolocco/Cecilia_Bolocco_0003.jpg',
#   './LFW_DIR/Cesar_Gaviria/Cesar_Gaviria_0002.jpg',
#   './LFW_DIR/Cesar_Gaviria/Cesar_Gaviria_0005.jpg',
#   './LFW_DIR/Cesar_Gaviria/Cesar_Gaviria_0004.jpg',
#   './LFW_DIR/Cesar_Gaviria/Cesar_Gaviria_0008.jpg',
#   './LFW_DIR/Cesar_Gaviria/Cesar_Gaviria_0006.jpg',
#   './LFW_DIR/Cesar_Gaviria/Cesar_Gaviria_0007.jpg',
#   './LFW_DIR/Charles_Grassley/Charles_Grassley_0001.jpg',
#   './LFW_DIR/Charles_Grassley/Charles_Grassley_0002.jpg',
#   './LFW_DIR/Charles_Moose/Charles_Moose_0001.jpg',
#   './LFW_DIR/Charles_Moose/Charles_Moose_0003.jpg',
#   './LFW_DIR/Charles_Moose/Charles_Moose_0004.jpg',
#   './LFW_DIR/Charles_Moose/Charles_Moose_0010.jpg',
#   './LFW_DIR/Charles_Moose/Charles_Moose_0004.jpg',
#   './LFW_DIR/Charles_Moose/Charles_Moose_0011.jpg',
#   './LFW_DIR/Charles_Schumer/Charles_Schumer_0001.jpg',
#   './LFW_DIR/Charles_Schumer/Charles_Schumer_0002.jpg',
#   './LFW_DIR/Charlotte_Rampling/Charlotte_Rampling_0001.jpg',
#   './LFW_DIR/Charlotte_Rampling/Charlotte_Rampling_0002.jpg',
#   './LFW_DIR/Chen_Liang_Yu/Chen_Liang_Yu_0001.jpg',
#   './LFW_DIR/Chen_Liang_Yu/Chen_Liang_Yu_0002.jpg',
#   './LFW_DIR/Cherie_Blair/Cherie_Blair_0001.jpg',
#   './LFW_DIR/Cherie_Blair/Cherie_Blair_0002.jpg',
#   './LFW_DIR/Cherie_Blair/Cherie_Blair_0001.jpg',
#   './LFW_DIR/Cherie_Blair/Cherie_Blair_0003.jpg',
#   './LFW_DIR/Cherie_Blair/Cherie_Blair_0002.jpg',
#   './LFW_DIR/Cherie_Blair/Cherie_Blair_0004.jpg',
#   './LFW_DIR/Cherie_Blair/Cherie_Blair_0003.jpg',
#   './LFW_DIR/Cherie_Blair/Cherie_Blair_0004.jpg',
#   './LFW_DIR/Choi_Sung-hong/Choi_Sung-hong_0001.jpg',
#   './LFW_DIR/Choi_Sung-hong/Choi_Sung-hong_0004.jpg',
#   './LFW_DIR/Choi_Sung-hong/Choi_Sung-hong_0003.jpg',
#   './LFW_DIR/Choi_Sung-hong/Choi_Sung-hong_0004.jpg',
#   './LFW_DIR/Chris_Cooper/Chris_Cooper_0001.jpg',
#   './LFW_DIR/Chris_Cooper/Chris_Cooper_0002.jpg',
#   './LFW_DIR/Chris_Rock/Chris_Rock_0001.jpg',
#   './LFW_DIR/Chris_Rock/Chris_Rock_0002.jpg',
#   './LFW_DIR/Chris_Tucker/Chris_Tucker_0001.jpg',
#   './LFW_DIR/Chris_Tucker/Chris_Tucker_0002.jpg',
#   './LFW_DIR/Christian_Fittipaldi/Christian_Fittipaldi_0001.jpg',
#   './LFW_DIR/Christian_Fittipaldi/Christian_Fittipaldi_0002.jpg',
#   './LFW_DIR/Christine_Gregoire/Christine_Gregoire_0002.jpg',
#   './LFW_DIR/Christine_Gregoire/Christine_Gregoire_0003.jpg',
#   './LFW_DIR/Christopher_Patten/Christopher_Patten_0001.jpg',
#   './LFW_DIR/Christopher_Patten/Christopher_Patten_0002.jpg',
#   './LFW_DIR/Christopher_Walken/Christopher_Walken_0001.jpg',
#   './LFW_DIR/Christopher_Walken/Christopher_Walken_0004.jpg',
#   './LFW_DIR/Christopher_Walken/Christopher_Walken_0002.jpg',
#   './LFW_DIR/Christopher_Walken/Christopher_Walken_0004.jpg',
#   './LFW_DIR/Chuck_Amato/Chuck_Amato_0001.jpg',
#   './LFW_DIR/Chuck_Amato/Chuck_Amato_0002.jpg',
#   './LFW_DIR/Chuck_Yeager/Chuck_Yeager_0001.jpg',
#   './LFW_DIR/Chuck_Yeager/Chuck_Yeager_0002.jpg',
#   './LFW_DIR/Chung_Mong-hun/Chung_Mong-hun_0001.jpg',
#   './LFW_DIR/Chung_Mong-hun/Chung_Mong-hun_0002.jpg',
#   './LFW_DIR/Cindy_Margolis/Cindy_Margolis_0001.jpg',
#   './LFW_DIR/Cindy_Margolis/Cindy_Margolis_0002.jpg',
#   './LFW_DIR/Ciro_Gomes/Ciro_Gomes_0002.jpg',
#   './LFW_DIR/Ciro_Gomes/Ciro_Gomes_0003.jpg',
#   './LFW_DIR/Ciro_Gomes/Ciro_Gomes_0002.jpg',
#   './LFW_DIR/Ciro_Gomes/Ciro_Gomes_0004.jpg',
#   './LFW_DIR/Ciro_Gomes/Ciro_Gomes_0003.jpg',
#   './LFW_DIR/Ciro_Gomes/Ciro_Gomes_0004.jpg',
#   './LFW_DIR/Claire_Hentzen/Claire_Hentzen_0001.jpg',
#   './LFW_DIR/Claire_Hentzen/Claire_Hentzen_0002.jpg',
#   './LFW_DIR/Clara_Harris/Clara_Harris_0001.jpg',
#   './LFW_DIR/Clara_Harris/Clara_Harris_0004.jpg',
#   './LFW_DIR/Clara_Harris/Clara_Harris_0002.jpg',
#   './LFW_DIR/Clara_Harris/Clara_Harris_0004.jpg',
#   './LFW_DIR/Claudia_Pechstein/Claudia_Pechstein_0001.jpg',
#   './LFW_DIR/Claudia_Pechstein/Claudia_Pechstein_0002.jpg',
#   './LFW_DIR/Claudia_Schiffer/Claudia_Schiffer_0001.jpg',
#   './LFW_DIR/Claudia_Schiffer/Claudia_Schiffer_0003.jpg',
#   './LFW_DIR/Clint_Eastwood/Clint_Eastwood_0001.jpg',
#   './LFW_DIR/Clint_Eastwood/Clint_Eastwood_0005.jpg',
#   './LFW_DIR/Clint_Eastwood/Clint_Eastwood_0001.jpg',
#   './LFW_DIR/Clint_Eastwood/Clint_Eastwood_0006.jpg',
#   './LFW_DIR/Clint_Eastwood/Clint_Eastwood_0003.jpg',
#   './LFW_DIR/Clint_Eastwood/Clint_Eastwood_0006.jpg',
#   './LFW_DIR/Colin_Farrell/Colin_Farrell_0001.jpg',
#   './LFW_DIR/Colin_Farrell/Colin_Farrell_0007.jpg',
#   './LFW_DIR/Colin_Farrell/Colin_Farrell_0003.jpg',
#   './LFW_DIR/Colin_Farrell/Colin_Farrell_0007.jpg',
#   './LFW_DIR/Colin_Jackson/Colin_Jackson_0001.jpg',
#   './LFW_DIR/Colin_Jackson/Colin_Jackson_0002.jpg',
#   './LFW_DIR/Colin_Montgomerie/Colin_Montgomerie_0002.jpg',
#   './LFW_DIR/Colin_Montgomerie/Colin_Montgomerie_0004.jpg',
#   './LFW_DIR/Colin_Montgomerie/Colin_Montgomerie_0002.jpg',
#   './LFW_DIR/Colin_Montgomerie/Colin_Montgomerie_0005.jpg',
#   './LFW_DIR/Colin_Powell/Colin_Powell_0038.jpg',
#   './LFW_DIR/Colin_Powell/Colin_Powell_0212.jpg',
#   './LFW_DIR/Colin_Powell/Colin_Powell_0074.jpg',
#   './LFW_DIR/Colin_Powell/Colin_Powell_0205.jpg',
#   './LFW_DIR/Colin_Powell/Colin_Powell_0120.jpg',
#   './LFW_DIR/Colin_Powell/Colin_Powell_0166.jpg',
#   './LFW_DIR/Conan_OBrien/Conan_OBrien_0001.jpg',
#   './LFW_DIR/Conan_OBrien/Conan_OBrien_0002.jpg',
#   './LFW_DIR/Constance_Marie/Constance_Marie_0002.jpg',
#   './LFW_DIR/Constance_Marie/Constance_Marie_0003.jpg',
#   './LFW_DIR/Coretta_Scott_King/Coretta_Scott_King_0002.jpg',
#   './LFW_DIR/Coretta_Scott_King/Coretta_Scott_King_0003.jpg',
#   './LFW_DIR/Corinne_Coman/Corinne_Coman_0001.jpg',
#   './LFW_DIR/Corinne_Coman/Corinne_Coman_0002.jpg',
#   './LFW_DIR/Costas_Simitis/Costas_Simitis_0001.jpg',
#   './LFW_DIR/Costas_Simitis/Costas_Simitis_0003.jpg',
#   './LFW_DIR/Costas_Simitis/Costas_Simitis_0002.jpg',
#   './LFW_DIR/Costas_Simitis/Costas_Simitis_0004.jpg',
#   './LFW_DIR/Cristina_Saralegui/Cristina_Saralegui_0001.jpg',
#   './LFW_DIR/Cristina_Saralegui/Cristina_Saralegui_0002.jpg',
#   './LFW_DIR/Cruz_Bustamante/Cruz_Bustamante_0001.jpg',
#   './LFW_DIR/Cruz_Bustamante/Cruz_Bustamante_0004.jpg',
#   './LFW_DIR/Dalai_Lama/Dalai_Lama_0001.jpg',
#   './LFW_DIR/Dalai_Lama/Dalai_Lama_0002.jpg',
#   './LFW_DIR/Dale_Earnhardt_Jr/Dale_Earnhardt_Jr_0001.jpg',
#   './LFW_DIR/Dale_Earnhardt_Jr/Dale_Earnhardt_Jr_0002.jpg',
#   './LFW_DIR/Dale_Earnhardt_Jr/Dale_Earnhardt_Jr_0001.jpg',
#   './LFW_DIR/Dale_Earnhardt_Jr/Dale_Earnhardt_Jr_0003.jpg',
#   './LFW_DIR/Damon_van_Dam/Damon_van_Dam_0001.jpg',
#   './LFW_DIR/Damon_van_Dam/Damon_van_Dam_0002.jpg',
#   './LFW_DIR/Dan_Morales/Dan_Morales_0001.jpg',
#   './LFW_DIR/Dan_Morales/Dan_Morales_0002.jpg',
#   './LFW_DIR/Dan_Morales/Dan_Morales_0001.jpg',
#   './LFW_DIR/Dan_Morales/Dan_Morales_0003.jpg',
#   './LFW_DIR/Daniel_Day-Lewis/Daniel_Day-Lewis_0001.jpg',
#   './LFW_DIR/Daniel_Day-Lewis/Daniel_Day-Lewis_0002.jpg',
#   './LFW_DIR/Daniel_Day-Lewis/Daniel_Day-Lewis_0001.jpg',
#   './LFW_DIR/Daniel_Day-Lewis/Daniel_Day-Lewis_0003.jpg',
#   './LFW_DIR/Darrell_Issa/Darrell_Issa_0001.jpg',
#   './LFW_DIR/Darrell_Issa/Darrell_Issa_0002.jpg',
#   './LFW_DIR/Darrell_Porter/Darrell_Porter_0001.jpg',
#   './LFW_DIR/Darrell_Porter/Darrell_Porter_0002.jpg',
#   './LFW_DIR/Darren_Clarke/Darren_Clarke_0001.jpg',
#   './LFW_DIR/Darren_Clarke/Darren_Clarke_0002.jpg',
#   './LFW_DIR/Daryl_Hannah/Daryl_Hannah_0001.jpg',
#   './LFW_DIR/Daryl_Hannah/Daryl_Hannah_0002.jpg',
#   './LFW_DIR/David_Anderson/David_Anderson_0001.jpg',
#   './LFW_DIR/David_Anderson/David_Anderson_0002.jpg',
#   './LFW_DIR/David_Anderson/David_Anderson_0002.jpg',
#   './LFW_DIR/David_Anderson/David_Anderson_0004.jpg',
#   './LFW_DIR/David_Beckham/David_Beckham_0004.jpg',
#   './LFW_DIR/David_Beckham/David_Beckham_0017.jpg',
#   './LFW_DIR/David_Beckham/David_Beckham_0004.jpg',
#   './LFW_DIR/David_Beckham/David_Beckham_0024.jpg',
#   './LFW_DIR/David_Beckham/David_Beckham_0005.jpg',
#   './LFW_DIR/David_Beckham/David_Beckham_0010.jpg',
#   './LFW_DIR/David_Caruso/David_Caruso_0001.jpg',
#   './LFW_DIR/David_Caruso/David_Caruso_0002.jpg',
#   './LFW_DIR/David_Coulthard/David_Coulthard_0001.jpg',
#   './LFW_DIR/David_Coulthard/David_Coulthard_0002.jpg',
#   './LFW_DIR/David_Dodge/David_Dodge_0001.jpg',
#   './LFW_DIR/David_Dodge/David_Dodge_0002.jpg',
#   './LFW_DIR/David_Heymann/David_Heymann_0001.jpg',
#   './LFW_DIR/David_Heymann/David_Heymann_0002.jpg',
#   './LFW_DIR/David_Hyde_Pierce/David_Hyde_Pierce_0003.jpg',
#   './LFW_DIR/David_Hyde_Pierce/David_Hyde_Pierce_0004.jpg',
#   './LFW_DIR/David_Myers/David_Myers_0001.jpg',
#   './LFW_DIR/David_Myers/David_Myers_0002.jpg',
#   './LFW_DIR/David_Nalbandian/David_Nalbandian_0004.jpg',
#   './LFW_DIR/David_Nalbandian/David_Nalbandian_0009.jpg',
#   './LFW_DIR/David_Spade/David_Spade_0001.jpg',
#   './LFW_DIR/David_Spade/David_Spade_0002.jpg',
#   './LFW_DIR/David_Wells/David_Wells_0001.jpg',
#   './LFW_DIR/David_Wells/David_Wells_0002.jpg',
#   './LFW_DIR/David_Wells/David_Wells_0002.jpg',
#   './LFW_DIR/David_Wells/David_Wells_0005.jpg',
#   './LFW_DIR/Dean_Barkley/Dean_Barkley_0001.jpg',
#   './LFW_DIR/Dean_Barkley/Dean_Barkley_0004.jpg',
#   './LFW_DIR/Dean_Barkley/Dean_Barkley_0002.jpg',
#   './LFW_DIR/Dean_Barkley/Dean_Barkley_0003.jpg',
#   './LFW_DIR/Debbie_Reynolds/Debbie_Reynolds_0001.jpg',
#   './LFW_DIR/Debbie_Reynolds/Debbie_Reynolds_0003.jpg',
#   './LFW_DIR/Debra_Brown/Debra_Brown_0001.jpg',
#   './LFW_DIR/Debra_Brown/Debra_Brown_0002.jpg',
#   './LFW_DIR/Demi_Moore/Demi_Moore_0001.jpg',
#   './LFW_DIR/Demi_Moore/Demi_Moore_0002.jpg',
#   './LFW_DIR/Demi_Moore/Demi_Moore_0002.jpg',
#   './LFW_DIR/Demi_Moore/Demi_Moore_0003.jpg',
#   './LFW_DIR/Demi_Moore/Demi_Moore_0002.jpg',
#   './LFW_DIR/Demi_Moore/Demi_Moore_0004.jpg',
#   './LFW_DIR/Dennis_Erickson/Dennis_Erickson_0001.jpg',
#   './LFW_DIR/Dennis_Erickson/Dennis_Erickson_0002.jpg',
#   './LFW_DIR/Dennis_Kucinich/Dennis_Kucinich_0002.jpg',
#   './LFW_DIR/Dennis_Kucinich/Dennis_Kucinich_0005.jpg',
#   './LFW_DIR/Dennis_Kucinich/Dennis_Kucinich_0006.jpg',
#   './LFW_DIR/Dennis_Kucinich/Dennis_Kucinich_0007.jpg',
#   './LFW_DIR/Derek_Lowe/Derek_Lowe_0001.jpg',
#   './LFW_DIR/Derek_Lowe/Derek_Lowe_0002.jpg',
#   './LFW_DIR/Desiree_Lemosi/Desiree_Lemosi_0001.jpg',
#   './LFW_DIR/Desiree_Lemosi/Desiree_Lemosi_0002.jpg',
#   './LFW_DIR/Dexter_Jackson/Dexter_Jackson_0001.jpg',
#   './LFW_DIR/Dexter_Jackson/Dexter_Jackson_0002.jpg',
#   './LFW_DIR/Diana_Krall/Diana_Krall_0001.jpg',
#   './LFW_DIR/Diana_Krall/Diana_Krall_0003.jpg',
#   './LFW_DIR/Diana_Krall/Diana_Krall_0001.jpg',
#   './LFW_DIR/Diana_Krall/Diana_Krall_0006.jpg',
#   './LFW_DIR/Diana_Krall/Diana_Krall_0002.jpg',
#   './LFW_DIR/Diana_Krall/Diana_Krall_0004.jpg',
#   './LFW_DIR/Diana_Munz/Diana_Munz_0002.jpg',
#   './LFW_DIR/Diana_Munz/Diana_Munz_0003.jpg',
#   './LFW_DIR/Dianne_Feinstein/Dianne_Feinstein_0002.jpg',
#   './LFW_DIR/Dianne_Feinstein/Dianne_Feinstein_0003.jpg',
#   './LFW_DIR/Dick_Cheney/Dick_Cheney_0001.jpg',
#   './LFW_DIR/Dick_Cheney/Dick_Cheney_0011.jpg',
#   './LFW_DIR/Dick_Cheney/Dick_Cheney_0001.jpg',
#   './LFW_DIR/Dick_Cheney/Dick_Cheney_0014.jpg',
#   './LFW_DIR/Dolly_Parton/Dolly_Parton_0001.jpg',
#   './LFW_DIR/Dolly_Parton/Dolly_Parton_0002.jpg',
#   './LFW_DIR/Dolma_Tsering/Dolma_Tsering_0001.jpg',
#   './LFW_DIR/Dolma_Tsering/Dolma_Tsering_0002.jpg',
#   './LFW_DIR/Don_Nickles/Don_Nickles_0001.jpg',
#   './LFW_DIR/Don_Nickles/Don_Nickles_0002.jpg',
#   './LFW_DIR/Don_Siegelman/Don_Siegelman_0002.jpg',
#   './LFW_DIR/Don_Siegelman/Don_Siegelman_0003.jpg',
#   './LFW_DIR/Donald_Evans/Donald_Evans_0001.jpg',
#   './LFW_DIR/Donald_Evans/Donald_Evans_0002.jpg',
#   './LFW_DIR/Donald_Fehr/Donald_Fehr_0003.jpg',
#   './LFW_DIR/Donald_Fehr/Donald_Fehr_0004.jpg',
#   './LFW_DIR/Doris_Roberts/Doris_Roberts_0001.jpg',
#   './LFW_DIR/Doris_Roberts/Doris_Roberts_0002.jpg',
#   './LFW_DIR/Doug_Duncan/Doug_Duncan_0001.jpg',
#   './LFW_DIR/Doug_Duncan/Doug_Duncan_0002.jpg',
#   './LFW_DIR/Drew_Barrymore/Drew_Barrymore_0001.jpg',
#   './LFW_DIR/Drew_Barrymore/Drew_Barrymore_0002.jpg',
#   './LFW_DIR/Duane_Lee_Chapman/Duane_Lee_Chapman_0001.jpg',
#   './LFW_DIR/Duane_Lee_Chapman/Duane_Lee_Chapman_0002.jpg',
#   './LFW_DIR/Dwayne_Johnson/Dwayne_Johnson_0001.jpg',
#   './LFW_DIR/Dwayne_Johnson/Dwayne_Johnson_0002.jpg',
#   './LFW_DIR/Eddy_Merckx/Eddy_Merckx_0001.jpg',
#   './LFW_DIR/Eddy_Merckx/Eddy_Merckx_0002.jpg',
#   './LFW_DIR/Edie_Falco/Edie_Falco_0001.jpg',
#   './LFW_DIR/Edie_Falco/Edie_Falco_0002.jpg',
#   './LFW_DIR/Edmund_Hillary/Edmund_Hillary_0002.jpg',
#   './LFW_DIR/Edmund_Hillary/Edmund_Hillary_0003.jpg',
#   './LFW_DIR/Edmund_Stoiber/Edmund_Stoiber_0002.jpg',
#   './LFW_DIR/Edmund_Stoiber/Edmund_Stoiber_0003.jpg',
#   './LFW_DIR/Eduard_Shevardnadze/Eduard_Shevardnadze_0001.jpg',
#   './LFW_DIR/Eduard_Shevardnadze/Eduard_Shevardnadze_0003.jpg',
#   './LFW_DIR/Eduard_Shevardnadze/Eduard_Shevardnadze_0003.jpg',
#   './LFW_DIR/Eduard_Shevardnadze/Eduard_Shevardnadze_0004.jpg',
#   './LFW_DIR/Eduardo_Duhalde/Eduardo_Duhalde_0005.jpg',
#   './LFW_DIR/Eduardo_Duhalde/Eduardo_Duhalde_0011.jpg',
#   './LFW_DIR/Edward_Kennedy/Edward_Kennedy_0001.jpg',
#   './LFW_DIR/Edward_Kennedy/Edward_Kennedy_0002.jpg',
#   './LFW_DIR/Edward_Said/Edward_Said_0001.jpg',
#   './LFW_DIR/Edward_Said/Edward_Said_0002.jpg',
#   './LFW_DIR/Edwina_Currie/Edwina_Currie_0002.jpg',
#   './LFW_DIR/Edwina_Currie/Edwina_Currie_0003.jpg',
#   './LFW_DIR/Eileen_Coparropa/Eileen_Coparropa_0002.jpg',
#   './LFW_DIR/Eileen_Coparropa/Eileen_Coparropa_0003.jpg',
#   './LFW_DIR/Elena_Bovina/Elena_Bovina_0001.jpg',
#   './LFW_DIR/Elena_Bovina/Elena_Bovina_0002.jpg',
#   './LFW_DIR/Elijah_Wood/Elijah_Wood_0002.jpg',
#   './LFW_DIR/Elijah_Wood/Elijah_Wood_0003.jpg',
#   './LFW_DIR/Elizabeth_Dole/Elizabeth_Dole_0001.jpg',
#   './LFW_DIR/Elizabeth_Dole/Elizabeth_Dole_0003.jpg',
#   './LFW_DIR/Elizabeth_Hurley/Elizabeth_Hurley_0001.jpg',
#   './LFW_DIR/Elizabeth_Hurley/Elizabeth_Hurley_0002.jpg',
#   './LFW_DIR/Elizabeth_Hurley/Elizabeth_Hurley_0002.jpg',
#   './LFW_DIR/Elizabeth_Hurley/Elizabeth_Hurley_0003.jpg',
#   './LFW_DIR/Elizabeth_Hurley/Elizabeth_Hurley_0004.jpg',
#   './LFW_DIR/Elizabeth_Hurley/Elizabeth_Hurley_0005.jpg',
#   './LFW_DIR/Elizabeth_Shue/Elizabeth_Shue_0001.jpg',
#   './LFW_DIR/Elizabeth_Shue/Elizabeth_Shue_0002.jpg',
#   './LFW_DIR/Ellen_DeGeneres/Ellen_DeGeneres_0001.jpg',
#   './LFW_DIR/Ellen_DeGeneres/Ellen_DeGeneres_0002.jpg',
#   './LFW_DIR/Elton_John/Elton_John_0001.jpg',
#   './LFW_DIR/Elton_John/Elton_John_0007.jpg',
#   './LFW_DIR/Elton_John/Elton_John_0003.jpg',
#   './LFW_DIR/Elton_John/Elton_John_0005.jpg',
#   './LFW_DIR/Elvis_Presley/Elvis_Presley_0001.jpg',
#   './LFW_DIR/Elvis_Presley/Elvis_Presley_0002.jpg',
#   './LFW_DIR/Emanuel_Ginobili/Emanuel_Ginobili_0002.jpg',
#   './LFW_DIR/Emanuel_Ginobili/Emanuel_Ginobili_0004.jpg',
#   './LFW_DIR/Emile_Lahoud/Emile_Lahoud_0001.jpg',
#   './LFW_DIR/Emile_Lahoud/Emile_Lahoud_0002.jpg',
#   './LFW_DIR/Emily_Robison/Emily_Robison_0001.jpg',
#   './LFW_DIR/Emily_Robison/Emily_Robison_0002.jpg',
#   './LFW_DIR/Emma_Thompson/Emma_Thompson_0001.jpg',
#   './LFW_DIR/Emma_Thompson/Emma_Thompson_0002.jpg',
#   './LFW_DIR/Emma_Thompson/Emma_Thompson_0001.jpg',
#   './LFW_DIR/Emma_Thompson/Emma_Thompson_0003.jpg',
#   './LFW_DIR/Emmanuelle_Beart/Emmanuelle_Beart_0001.jpg',
#   './LFW_DIR/Emmanuelle_Beart/Emmanuelle_Beart_0002.jpg',
#   './LFW_DIR/Emmanuelle_Beart/Emmanuelle_Beart_0002.jpg',
#   './LFW_DIR/Emmanuelle_Beart/Emmanuelle_Beart_0003.jpg',
#   './LFW_DIR/Emmit_Smith/Emmit_Smith_0001.jpg',
#   './LFW_DIR/Emmit_Smith/Emmit_Smith_0002.jpg',
#   './LFW_DIR/Enrique_Bolanos/Enrique_Bolanos_0001.jpg',
#   './LFW_DIR/Enrique_Bolanos/Enrique_Bolanos_0002.jpg',
#   './LFW_DIR/Enrique_Bolanos/Enrique_Bolanos_0002.jpg',
#   './LFW_DIR/Enrique_Bolanos/Enrique_Bolanos_0005.jpg',
#   './LFW_DIR/Enrique_Bolanos/Enrique_Bolanos_0004.jpg',
#   './LFW_DIR/Enrique_Bolanos/Enrique_Bolanos_0005.jpg',
#   './LFW_DIR/Eric_Clapton/Eric_Clapton_0001.jpg',
#   './LFW_DIR/Eric_Clapton/Eric_Clapton_0002.jpg',
#   './LFW_DIR/Eric_Rosser/Eric_Rosser_0001.jpg',
#   './LFW_DIR/Eric_Rosser/Eric_Rosser_0002.jpg',
#   './LFW_DIR/Erika_Harold/Erika_Harold_0002.jpg',
#   './LFW_DIR/Erika_Harold/Erika_Harold_0005.jpg',
#   './LFW_DIR/Ernesto_Zedillo/Ernesto_Zedillo_0001.jpg',
#   './LFW_DIR/Ernesto_Zedillo/Ernesto_Zedillo_0002.jpg',
#   './LFW_DIR/Ernie_Els/Ernie_Els_0001.jpg',
#   './LFW_DIR/Ernie_Els/Ernie_Els_0003.jpg',
#   './LFW_DIR/Ethan_Hawke/Ethan_Hawke_0001.jpg',
#   './LFW_DIR/Ethan_Hawke/Ethan_Hawke_0004.jpg',
#   './LFW_DIR/Ethan_Hawke/Ethan_Hawke_0002.jpg',
#   './LFW_DIR/Ethan_Hawke/Ethan_Hawke_0004.jpg',
#   './LFW_DIR/Ethan_Hawke/Ethan_Hawke_0003.jpg',
#   './LFW_DIR/Ethan_Hawke/Ethan_Hawke_0004.jpg',
#   './LFW_DIR/Eunice_Barber/Eunice_Barber_0001.jpg',
#   './LFW_DIR/Eunice_Barber/Eunice_Barber_0002.jpg',
#   './LFW_DIR/Eva_Dimas/Eva_Dimas_0001.jpg',
#   './LFW_DIR/Eva_Dimas/Eva_Dimas_0002.jpg',
#   './LFW_DIR/Evander_Holyfield/Evander_Holyfield_0001.jpg',
#   './LFW_DIR/Evander_Holyfield/Evander_Holyfield_0002.jpg',
#   './LFW_DIR/Eve_Pelletier/Eve_Pelletier_0001.jpg',
#   './LFW_DIR/Eve_Pelletier/Eve_Pelletier_0002.jpg',
#   './LFW_DIR/Farouk_al-Sharaa/Farouk_al-Sharaa_0001.jpg',
#   './LFW_DIR/Farouk_al-Sharaa/Farouk_al-Sharaa_0003.jpg',
#   './LFW_DIR/Farouk_al-Sharaa/Farouk_al-Sharaa_0002.jpg',
#   './LFW_DIR/Farouk_al-Sharaa/Farouk_al-Sharaa_0003.jpg',
#   './LFW_DIR/Federico_Trillo/Federico_Trillo_0001.jpg',
#   './LFW_DIR/Federico_Trillo/Federico_Trillo_0003.jpg',
#   './LFW_DIR/Felix_Mantilla/Felix_Mantilla_0001.jpg',
#   './LFW_DIR/Felix_Mantilla/Felix_Mantilla_0002.jpg',
#   './LFW_DIR/Fernando_Gonzalez/Fernando_Gonzalez_0002.jpg',
#   './LFW_DIR/Fernando_Gonzalez/Fernando_Gonzalez_0006.jpg',
#   './LFW_DIR/Fernando_Gonzalez/Fernando_Gonzalez_0004.jpg',
#   './LFW_DIR/Fernando_Gonzalez/Fernando_Gonzalez_0007.jpg',
#   './LFW_DIR/Fernando_Henrique_Cardoso/Fernando_Henrique_Cardoso_0001.jpg',
#   './LFW_DIR/Fernando_Henrique_Cardoso/Fernando_Henrique_Cardoso_0003.jpg',
#   './LFW_DIR/Fidel_Castro/Fidel_Castro_0004.jpg',
#   './LFW_DIR/Fidel_Castro/Fidel_Castro_0014.jpg',
#   './LFW_DIR/Flavia_Delaroli/Flavia_Delaroli_0001.jpg',
#   './LFW_DIR/Flavia_Delaroli/Flavia_Delaroli_0002.jpg',
#   './LFW_DIR/Frances_Fisher/Frances_Fisher_0001.jpg',
#   './LFW_DIR/Frances_Fisher/Frances_Fisher_0002.jpg',
#   './LFW_DIR/Francis_Ford_Coppola/Francis_Ford_Coppola_0001.jpg',
#   './LFW_DIR/Francis_Ford_Coppola/Francis_Ford_Coppola_0002.jpg',
#   './LFW_DIR/Francisco_Flores/Francisco_Flores_0003.jpg',
#   './LFW_DIR/Francisco_Flores/Francisco_Flores_0004.jpg',
#   './LFW_DIR/Frank_Griswold/Frank_Griswold_0001.jpg',
#   './LFW_DIR/Frank_Griswold/Frank_Griswold_0002.jpg',
#   './LFW_DIR/Frank_Solich/Frank_Solich_0001.jpg',
#   './LFW_DIR/Frank_Solich/Frank_Solich_0002.jpg',
#   './LFW_DIR/Frank_Solich/Frank_Solich_0003.jpg',
#   './LFW_DIR/Frank_Solich/Frank_Solich_0004.jpg',
#   './LFW_DIR/Franz_Muentefering/Franz_Muentefering_0001.jpg',
#   './LFW_DIR/Franz_Muentefering/Franz_Muentefering_0003.jpg',
#   './LFW_DIR/Franz_Muentefering/Franz_Muentefering_0001.jpg',
#   './LFW_DIR/Franz_Muentefering/Franz_Muentefering_0004.jpg',
#   './LFW_DIR/Franz_Muentefering/Franz_Muentefering_0002.jpg',
#   './LFW_DIR/Franz_Muentefering/Franz_Muentefering_0003.jpg',
#   './LFW_DIR/Fred_Thompson/Fred_Thompson_0002.jpg',
#   './LFW_DIR/Fred_Thompson/Fred_Thompson_0003.jpg',
#   './LFW_DIR/Fujio_Cho/Fujio_Cho_0001.jpg',
#   './LFW_DIR/Fujio_Cho/Fujio_Cho_0005.jpg',
#   './LFW_DIR/Gabriel_Valdes/Gabriel_Valdes_0001.jpg',
#   './LFW_DIR/Gabriel_Valdes/Gabriel_Valdes_0002.jpg',
#   './LFW_DIR/Garry_Kasparov/Garry_Kasparov_0001.jpg',
#   './LFW_DIR/Garry_Kasparov/Garry_Kasparov_0002.jpg',
#   './LFW_DIR/Gary_Carter/Gary_Carter_0001.jpg',
#   './LFW_DIR/Gary_Carter/Gary_Carter_0002.jpg',
#   './LFW_DIR/Gary_Carter/Gary_Carter_0001.jpg',
#   './LFW_DIR/Gary_Carter/Gary_Carter_0003.jpg',
#   './LFW_DIR/Gary_Forsee/Gary_Forsee_0001.jpg',
#   './LFW_DIR/Gary_Forsee/Gary_Forsee_0002.jpg',
#   './LFW_DIR/Gary_Locke/Gary_Locke_0001.jpg',
#   './LFW_DIR/Gary_Locke/Gary_Locke_0002.jpg',
#   './LFW_DIR/George_Clooney/George_Clooney_0002.jpg',
#   './LFW_DIR/George_Clooney/George_Clooney_0008.jpg',
#   './LFW_DIR/George_Clooney/George_Clooney_0003.jpg',
#   './LFW_DIR/George_Clooney/George_Clooney_0009.jpg',
#   './LFW_DIR/George_Clooney/George_Clooney_0005.jpg',
#   './LFW_DIR/George_Clooney/George_Clooney_0007.jpg',
#   './LFW_DIR/George_Galloway/George_Galloway_0001.jpg',
#   './LFW_DIR/George_Galloway/George_Galloway_0004.jpg',
#   './LFW_DIR/George_HW_Bush/George_HW_Bush_0001.jpg',
#   './LFW_DIR/George_HW_Bush/George_HW_Bush_0010.jpg',
#   './LFW_DIR/George_HW_Bush/George_HW_Bush_0005.jpg',
#   './LFW_DIR/George_HW_Bush/George_HW_Bush_0013.jpg',
#   './LFW_DIR/George_HW_Bush/George_HW_Bush_0010.jpg',
#   './LFW_DIR/George_HW_Bush/George_HW_Bush_0013.jpg',
#   './LFW_DIR/George_Lopez/George_Lopez_0001.jpg',
#   './LFW_DIR/George_Lopez/George_Lopez_0004.jpg',
#   './LFW_DIR/George_P_Bush/George_P_Bush_0001.jpg',
#   './LFW_DIR/George_P_Bush/George_P_Bush_0002.jpg',
#   './LFW_DIR/George_Pataki/George_Pataki_0001.jpg',
#   './LFW_DIR/George_Pataki/George_Pataki_0005.jpg',
#   './LFW_DIR/George_Roy_Hill/George_Roy_Hill_0001.jpg',
#   './LFW_DIR/George_Roy_Hill/George_Roy_Hill_0002.jpg',
#   './LFW_DIR/George_Voinovich/George_Voinovich_0001.jpg',
#   './LFW_DIR/George_Voinovich/George_Voinovich_0002.jpg',
#   './LFW_DIR/George_Voinovich/George_Voinovich_0001.jpg',
#   './LFW_DIR/George_Voinovich/George_Voinovich_0003.jpg',
#   './LFW_DIR/Gerardo_Gambala/Gerardo_Gambala_0001.jpg',
#   './LFW_DIR/Gerardo_Gambala/Gerardo_Gambala_0002.jpg',
#   './LFW_DIR/Gerry_Parsky/Gerry_Parsky_0001.jpg',
#   './LFW_DIR/Gerry_Parsky/Gerry_Parsky_0002.jpg',
#   './LFW_DIR/Gian_Marco/Gian_Marco_0002.jpg',
#   './LFW_DIR/Gian_Marco/Gian_Marco_0003.jpg',
#   './LFW_DIR/Gil_de_Ferran/Gil_de_Ferran_0002.jpg',
#   './LFW_DIR/Gil_de_Ferran/Gil_de_Ferran_0003.jpg',
#   './LFW_DIR/Gisele_Bundchen/Gisele_Bundchen_0001.jpg',
#   './LFW_DIR/Gisele_Bundchen/Gisele_Bundchen_0002.jpg',
#   './LFW_DIR/Gloria_Allred/Gloria_Allred_0001.jpg',
#   './LFW_DIR/Gloria_Allred/Gloria_Allred_0002.jpg',
#   './LFW_DIR/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0029.jpg',
#   './LFW_DIR/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0040.jpg',
#   './LFW_DIR/Gloria_Trevi/Gloria_Trevi_0001.jpg',
#   './LFW_DIR/Gloria_Trevi/Gloria_Trevi_0003.jpg',
#   './LFW_DIR/Gloria_Trevi/Gloria_Trevi_0002.jpg',
#   './LFW_DIR/Gloria_Trevi/Gloria_Trevi_0004.jpg',
#   './LFW_DIR/Gloria_Trevi/Gloria_Trevi_0003.jpg',
#   './LFW_DIR/Gloria_Trevi/Gloria_Trevi_0004.jpg',
#   './LFW_DIR/Goldie_Hawn/Goldie_Hawn_0002.jpg',
#   './LFW_DIR/Goldie_Hawn/Goldie_Hawn_0006.jpg',
#   './LFW_DIR/Gonzalo_Sanchez_de_Lozada/Gonzalo_Sanchez_de_Lozada_0003.jpg',
#   './LFW_DIR/Gonzalo_Sanchez_de_Lozada/Gonzalo_Sanchez_de_Lozada_0010.jpg',
#   './LFW_DIR/Gonzalo_Sanchez_de_Lozada/Gonzalo_Sanchez_de_Lozada_0004.jpg',
#   './LFW_DIR/Gonzalo_Sanchez_de_Lozada/Gonzalo_Sanchez_de_Lozada_0008.jpg',
#   './LFW_DIR/Gonzalo_Sanchez_de_Lozada/Gonzalo_Sanchez_de_Lozada_0007.jpg',
#   './LFW_DIR/Gonzalo_Sanchez_de_Lozada/Gonzalo_Sanchez_de_Lozada_0008.jpg',
#   './LFW_DIR/Goran_Persson/Goran_Persson_0001.jpg',
#   './LFW_DIR/Goran_Persson/Goran_Persson_0002.jpg',
#   './LFW_DIR/Grady_Irvin_Jr/Grady_Irvin_Jr_0001.jpg',
#   './LFW_DIR/Grady_Irvin_Jr/Grady_Irvin_Jr_0002.jpg',
#   './LFW_DIR/Grant_Hackett/Grant_Hackett_0002.jpg',
#   './LFW_DIR/Grant_Hackett/Grant_Hackett_0003.jpg',
#   './LFW_DIR/Greg_Rusedski/Greg_Rusedski_0001.jpg',
#   './LFW_DIR/Greg_Rusedski/Greg_Rusedski_0004.jpg',
#   './LFW_DIR/Greg_Rusedski/Greg_Rusedski_0002.jpg',
#   './LFW_DIR/Greg_Rusedski/Greg_Rusedski_0004.jpg',
#   './LFW_DIR/Greg_Rusedski/Greg_Rusedski_0003.jpg',
#   './LFW_DIR/Greg_Rusedski/Greg_Rusedski_0004.jpg',
#   './LFW_DIR/Gregg_Popovich/Gregg_Popovich_0003.jpg',
#   './LFW_DIR/Gregg_Popovich/Gregg_Popovich_0004.jpg',
#   './LFW_DIR/Guillaume_Soro/Guillaume_Soro_0001.jpg',
#   './LFW_DIR/Guillaume_Soro/Guillaume_Soro_0002.jpg',
#   './LFW_DIR/Guillermo_Canas/Guillermo_Canas_0001.jpg',
#   './LFW_DIR/Guillermo_Canas/Guillermo_Canas_0002.jpg',
#   './LFW_DIR/Guillermo_Canas/Guillermo_Canas_0001.jpg',
#   './LFW_DIR/Guillermo_Canas/Guillermo_Canas_0004.jpg',
#   './LFW_DIR/Guillermo_Canas/Guillermo_Canas_0002.jpg',
#   './LFW_DIR/Guillermo_Canas/Guillermo_Canas_0004.jpg',
#   './LFW_DIR/Guillermo_Coria/Guillermo_Coria_0019.jpg',
#   './LFW_DIR/Guillermo_Coria/Guillermo_Coria_0029.jpg',
#   './LFW_DIR/Guillermo_Coria/Guillermo_Coria_0021.jpg',
#   './LFW_DIR/Guillermo_Coria/Guillermo_Coria_0027.jpg',
#   './LFW_DIR/Guillermo_Ortiz/Guillermo_Ortiz_0001.jpg',
#   './LFW_DIR/Guillermo_Ortiz/Guillermo_Ortiz_0002.jpg',
#   './LFW_DIR/Gunter_Pleuger/Gunter_Pleuger_0002.jpg',
#   './LFW_DIR/Gunter_Pleuger/Gunter_Pleuger_0005.jpg',
#   './LFW_DIR/Gustavo_Kuerten/Gustavo_Kuerten_0001.jpg',
#   './LFW_DIR/Gustavo_Kuerten/Gustavo_Kuerten_0002.jpg',
#   './LFW_DIR/Gustavo_Kuerten/Gustavo_Kuerten_0002.jpg',
#   './LFW_DIR/Gustavo_Kuerten/Gustavo_Kuerten_0003.jpg',
#   './LFW_DIR/Habib_Rizieq/Habib_Rizieq_0004.jpg',
#   './LFW_DIR/Habib_Rizieq/Habib_Rizieq_0005.jpg',
#   './LFW_DIR/Hal_Gehman/Hal_Gehman_0001.jpg',
#   './LFW_DIR/Hal_Gehman/Hal_Gehman_0003.jpg',
#   './LFW_DIR/Hal_Sutton/Hal_Sutton_0001.jpg',
#   './LFW_DIR/Hal_Sutton/Hal_Sutton_0002.jpg',
#   './LFW_DIR/Halle_Berry/Halle_Berry_0001.jpg',
#   './LFW_DIR/Halle_Berry/Halle_Berry_0010.jpg',
#   './LFW_DIR/Halle_Berry/Halle_Berry_0007.jpg',
#   './LFW_DIR/Halle_Berry/Halle_Berry_0015.jpg',
#   './LFW_DIR/Halle_Berry/Halle_Berry_0010.jpg',
#   './LFW_DIR/Halle_Berry/Halle_Berry_0016.jpg',
#   './LFW_DIR/Hamid_Karzai/Hamid_Karzai_0001.jpg',
#   './LFW_DIR/Hamid_Karzai/Hamid_Karzai_0002.jpg',
#   './LFW_DIR/Hamzah_Haz/Hamzah_Haz_0001.jpg',
#   './LFW_DIR/Hamzah_Haz/Hamzah_Haz_0002.jpg',
#   './LFW_DIR/Hanan_Ashrawi/Hanan_Ashrawi_0001.jpg',
#   './LFW_DIR/Hanan_Ashrawi/Hanan_Ashrawi_0002.jpg',
#   './LFW_DIR/Hans_Blix/Hans_Blix_0002.jpg',
#   './LFW_DIR/Hans_Blix/Hans_Blix_0003.jpg',
#   './LFW_DIR/Hans_Blix/Hans_Blix_0006.jpg',
#   './LFW_DIR/Hans_Blix/Hans_Blix_0036.jpg',
#   './LFW_DIR/Hans_Blix/Hans_Blix_0014.jpg',
#   './LFW_DIR/Hans_Blix/Hans_Blix_0036.jpg',
#   './LFW_DIR/Harbhajan_Singh/Harbhajan_Singh_0001.jpg',
#   './LFW_DIR/Harbhajan_Singh/Harbhajan_Singh_0002.jpg',
#   './LFW_DIR/Hashim_Thaci/Hashim_Thaci_0001.jpg',
#   './LFW_DIR/Hashim_Thaci/Hashim_Thaci_0002.jpg',
#   './LFW_DIR/Hassan_Nasrallah/Hassan_Nasrallah_0001.jpg',
#   './LFW_DIR/Hassan_Nasrallah/Hassan_Nasrallah_0002.jpg',
#   './LFW_DIR/Heath_Ledger/Heath_Ledger_0001.jpg',
#   './LFW_DIR/Heath_Ledger/Heath_Ledger_0002.jpg',
#   './LFW_DIR/Hector_Babenco/Hector_Babenco_0001.jpg',
#   './LFW_DIR/Hector_Babenco/Hector_Babenco_0002.jpg',
#   './LFW_DIR/Hee-Won_Han/Hee-Won_Han_0001.jpg',
#   './LFW_DIR/Hee-Won_Han/Hee-Won_Han_0003.jpg',
#   './LFW_DIR/Heidi_Klum/Heidi_Klum_0001.jpg',
#   './LFW_DIR/Heidi_Klum/Heidi_Klum_0003.jpg',
#   './LFW_DIR/Helen_Clark/Helen_Clark_0003.jpg',
#   './LFW_DIR/Helen_Clark/Helen_Clark_0004.jpg',
#   './LFW_DIR/Henrique_Meirelles/Henrique_Meirelles_0001.jpg',
#   './LFW_DIR/Henrique_Meirelles/Henrique_Meirelles_0002.jpg',
#   './LFW_DIR/Herta_Daeubler-Gmelin/Herta_Daeubler-Gmelin_0001.jpg',
#   './LFW_DIR/Herta_Daeubler-Gmelin/Herta_Daeubler-Gmelin_0002.jpg',
#   './LFW_DIR/Hideki_Matsui/Hideki_Matsui_0001.jpg',
#   './LFW_DIR/Hideki_Matsui/Hideki_Matsui_0002.jpg',
#   './LFW_DIR/Hilary_Duff/Hilary_Duff_0001.jpg',
#   './LFW_DIR/Hilary_Duff/Hilary_Duff_0003.jpg',
#   './LFW_DIR/Hilary_Duff/Hilary_Duff_0002.jpg',
#   './LFW_DIR/Hilary_Duff/Hilary_Duff_0003.jpg',
#   './LFW_DIR/Hillary_Clinton/Hillary_Clinton_0001.jpg',
#   './LFW_DIR/Hillary_Clinton/Hillary_Clinton_0014.jpg',
#   './LFW_DIR/Hillary_Clinton/Hillary_Clinton_0008.jpg',
#   './LFW_DIR/Hillary_Clinton/Hillary_Clinton_0014.jpg',
#   './LFW_DIR/Hilmi_Ozkok/Hilmi_Ozkok_0001.jpg',
#   './LFW_DIR/Hilmi_Ozkok/Hilmi_Ozkok_0002.jpg',
#   './LFW_DIR/Hipolito_Mejia/Hipolito_Mejia_0001.jpg',
#   './LFW_DIR/Hipolito_Mejia/Hipolito_Mejia_0003.jpg',
#   './LFW_DIR/Hisao_Oguchi/Hisao_Oguchi_0001.jpg',
#   './LFW_DIR/Hisao_Oguchi/Hisao_Oguchi_0002.jpg',
#   './LFW_DIR/Holly_Hunter/Holly_Hunter_0002.jpg',
#   './LFW_DIR/Holly_Hunter/Holly_Hunter_0003.jpg',
#   './LFW_DIR/Holly_Hunter/Holly_Hunter_0002.jpg',
#   './LFW_DIR/Holly_Hunter/Holly_Hunter_0005.jpg',
#   './LFW_DIR/Holly_Hunter/Holly_Hunter_0004.jpg',
#   './LFW_DIR/Holly_Hunter/Holly_Hunter_0007.jpg',
#   './LFW_DIR/Hootie_Johnson/Hootie_Johnson_0001.jpg',
#   './LFW_DIR/Hootie_Johnson/Hootie_Johnson_0002.jpg',
#   './LFW_DIR/Hosni_Mubarak/Hosni_Mubarak_0008.jpg',
#   './LFW_DIR/Hosni_Mubarak/Hosni_Mubarak_0009.jpg',
#   './LFW_DIR/Hu_Jintao/Hu_Jintao_0001.jpg',
#   './LFW_DIR/Hu_Jintao/Hu_Jintao_0002.jpg',
#   './LFW_DIR/Hu_Jintao/Hu_Jintao_0001.jpg',
#   './LFW_DIR/Hu_Jintao/Hu_Jintao_0012.jpg',
#   './LFW_DIR/Hu_Jintao/Hu_Jintao_0002.jpg',
#   './LFW_DIR/Hu_Jintao/Hu_Jintao_0003.jpg',
#   './LFW_DIR/Hugh_Grant/Hugh_Grant_0001.jpg',
#   './LFW_DIR/Hugh_Grant/Hugh_Grant_0007.jpg',
#   './LFW_DIR/Hugh_Grant/Hugh_Grant_0001.jpg',
#   './LFW_DIR/Hugh_Grant/Hugh_Grant_0009.jpg',
#   './LFW_DIR/Hun_Sen/Hun_Sen_0001.jpg',
#   './LFW_DIR/Hun_Sen/Hun_Sen_0002.jpg',
#   './LFW_DIR/Hun_Sen/Hun_Sen_0001.jpg',
#   './LFW_DIR/Hun_Sen/Hun_Sen_0004.jpg',
#   './LFW_DIR/Ian_McKellen/Ian_McKellen_0001.jpg',
#   './LFW_DIR/Ian_McKellen/Ian_McKellen_0002.jpg',
#   './LFW_DIR/Ian_McKellen/Ian_McKellen_0001.jpg',
#   './LFW_DIR/Ian_McKellen/Ian_McKellen_0003.jpg',
#   './LFW_DIR/Ian_McKellen/Ian_McKellen_0002.jpg',
#   './LFW_DIR/Ian_McKellen/Ian_McKellen_0003.jpg',
#   './LFW_DIR/Ibrahim_Jaafari/Ibrahim_Jaafari_0001.jpg',
#   './LFW_DIR/Ibrahim_Jaafari/Ibrahim_Jaafari_0002.jpg',
#   './LFW_DIR/Igor_Ivanov/Igor_Ivanov_0005.jpg',
#   './LFW_DIR/Igor_Ivanov/Igor_Ivanov_0016.jpg',
#   './LFW_DIR/Ilan_Ramon/Ilan_Ramon_0001.jpg',
#   './LFW_DIR/Ilan_Ramon/Ilan_Ramon_0003.jpg',
#   './LFW_DIR/Inam-ul-Haq/Inam-ul-Haq_0001.jpg',
#   './LFW_DIR/Inam-ul-Haq/Inam-ul-Haq_0002.jpg',
#   './LFW_DIR/Inocencio_Arias/Inocencio_Arias_0001.jpg',
#   './LFW_DIR/Inocencio_Arias/Inocencio_Arias_0002.jpg',
#   './LFW_DIR/Intisar_Ajouri/Intisar_Ajouri_0002.jpg',
#   './LFW_DIR/Intisar_Ajouri/Intisar_Ajouri_0003.jpg',
#   './LFW_DIR/Jack_Straw/Jack_Straw_0004.jpg',
#   './LFW_DIR/Jack_Straw/Jack_Straw_0022.jpg',
#   './LFW_DIR/Jackie_Chan/Jackie_Chan_0001.jpg',
#   './LFW_DIR/Jackie_Chan/Jackie_Chan_0010.jpg',
#   './LFW_DIR/Jackie_Chan/Jackie_Chan_0007.jpg',
#   './LFW_DIR/Jackie_Chan/Jackie_Chan_0012.jpg',
#   './LFW_DIR/Jacqueline_Obradors/Jacqueline_Obradors_0001.jpg',
#   './LFW_DIR/Jacqueline_Obradors/Jacqueline_Obradors_0002.jpg',
#   './LFW_DIR/Jada_Pinkett_Smith/Jada_Pinkett_Smith_0001.jpg',
#   './LFW_DIR/Jada_Pinkett_Smith/Jada_Pinkett_Smith_0002.jpg',
#   './LFW_DIR/James_Caan/James_Caan_0001.jpg',
#   './LFW_DIR/James_Caan/James_Caan_0002.jpg',
#   './LFW_DIR/James_Cunningham/James_Cunningham_0001.jpg',
#   './LFW_DIR/James_Cunningham/James_Cunningham_0002.jpg',
#   './LFW_DIR/James_Cunningham/James_Cunningham_0002.jpg',
#   './LFW_DIR/James_Cunningham/James_Cunningham_0003.jpg',
#   './LFW_DIR/James_Gandolfini/James_Gandolfini_0001.jpg',
#   './LFW_DIR/James_Gandolfini/James_Gandolfini_0003.jpg',
#   './LFW_DIR/James_Jones/James_Jones_0001.jpg',
#   './LFW_DIR/James_Jones/James_Jones_0002.jpg',
#   './LFW_DIR/James_Parker/James_Parker_0001.jpg',
#   './LFW_DIR/James_Parker/James_Parker_0002.jpg',
#   './LFW_DIR/James_Schultz/James_Schultz_0001.jpg',
#   './LFW_DIR/James_Schultz/James_Schultz_0002.jpg',
#   './LFW_DIR/James_Traficant/James_Traficant_0001.jpg',
#   './LFW_DIR/James_Traficant/James_Traficant_0002.jpg',
#   './LFW_DIR/James_Traficant/James_Traficant_0001.jpg',
#   './LFW_DIR/James_Traficant/James_Traficant_0003.jpg',
#   './LFW_DIR/James_Wolfensohn/James_Wolfensohn_0001.jpg',
#   './LFW_DIR/James_Wolfensohn/James_Wolfensohn_0003.jpg',
#   './LFW_DIR/Jan-Michael_Gambill/Jan-Michael_Gambill_0001.jpg',
#   './LFW_DIR/Jan-Michael_Gambill/Jan-Michael_Gambill_0003.jpg',
#   './LFW_DIR/Jane_Fonda/Jane_Fonda_0001.jpg',
#   './LFW_DIR/Jane_Fonda/Jane_Fonda_0002.jpg',
#   './LFW_DIR/Jane_Pauley/Jane_Pauley_0001.jpg',
#   './LFW_DIR/Jane_Pauley/Jane_Pauley_0002.jpg',
#   './LFW_DIR/Janet_Napolitano/Janet_Napolitano_0001.jpg',
#   './LFW_DIR/Janet_Napolitano/Janet_Napolitano_0004.jpg',
#   './LFW_DIR/Janet_Napolitano/Janet_Napolitano_0002.jpg',
#   './LFW_DIR/Janet_Napolitano/Janet_Napolitano_0003.jpg',
#   './LFW_DIR/Jason_Jennings/Jason_Jennings_0001.jpg',
#   './LFW_DIR/Jason_Jennings/Jason_Jennings_0002.jpg',
#   './LFW_DIR/Jason_Kidd/Jason_Kidd_0001.jpg',
#   './LFW_DIR/Jason_Kidd/Jason_Kidd_0004.jpg',
#   './LFW_DIR/Jason_Kidd/Jason_Kidd_0001.jpg',
#   './LFW_DIR/Jason_Kidd/Jason_Kidd_0010.jpg',
#   './LFW_DIR/Jason_Kidd/Jason_Kidd_0005.jpg',
#   './LFW_DIR/Jason_Kidd/Jason_Kidd_0006.jpg',
#   './LFW_DIR/Jason_Kidd/Jason_Kidd_0006.jpg',
#   './LFW_DIR/Jason_Kidd/Jason_Kidd_0009.jpg',
#   './LFW_DIR/Jason_Kidd/Jason_Kidd_0006.jpg',
#   './LFW_DIR/Jason_Kidd/Jason_Kidd_0010.jpg',
#   './LFW_DIR/Javier_Solana/Javier_Solana_0002.jpg',
#   './LFW_DIR/Javier_Solana/Javier_Solana_0006.jpg',
#   './LFW_DIR/Javier_Solana/Javier_Solana_0006.jpg',
#   './LFW_DIR/Javier_Solana/Javier_Solana_0007.jpg',
#   './LFW_DIR/Jay_Leno/Jay_Leno_0002.jpg',
#   './LFW_DIR/Jay_Leno/Jay_Leno_0003.jpg',
#   './LFW_DIR/Jayson_Williams/Jayson_Williams_0001.jpg',
#   './LFW_DIR/Jayson_Williams/Jayson_Williams_0002.jpg',
#   './LFW_DIR/Jean-Claude_Braquet/Jean-Claude_Braquet_0001.jpg',
#   './LFW_DIR/Jean-Claude_Braquet/Jean-Claude_Braquet_0002.jpg',
#   './LFW_DIR/Jean-David_Levitte/Jean-David_Levitte_0003.jpg',
#   './LFW_DIR/Jean-David_Levitte/Jean-David_Levitte_0004.jpg',
#   './LFW_DIR/Jean-David_Levitte/Jean-David_Levitte_0006.jpg',
#   './LFW_DIR/Jean-David_Levitte/Jean-David_Levitte_0007.jpg',
#   './LFW_DIR/Jean-David_Levitte/Jean-David_Levitte_0008.jpg',
#   './LFW_DIR/Jean-David_Levitte/Jean-David_Levitte_0010.jpg',
#   './LFW_DIR/Jean-Francois_Pontal/Jean-Francois_Pontal_0001.jpg',
#   './LFW_DIR/Jean-Francois_Pontal/Jean-Francois_Pontal_0003.jpg',
#   './LFW_DIR/Jean-Sebastien_Giguere/Jean-Sebastien_Giguere_0001.jpg',
#   './LFW_DIR/Jean-Sebastien_Giguere/Jean-Sebastien_Giguere_0002.jpg',
#   ...],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   ...])
